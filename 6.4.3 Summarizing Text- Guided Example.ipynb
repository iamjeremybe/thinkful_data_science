# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import networkx as nx
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
# %matplotlib inline

# %% [markdown]
# # Summarizing Text
#
# Let's try out extractive summarization using the first four paragraphs of [The Great Gatsby](http://gutenberg.net.au/ebooks02/0200041h.html).
#
# First, we'll try to extract the most representative sentence.  Then, we'll extract keywords.
#
# ## Sentence extraction
#
# The steps of our sentence extraction process:
#
# 1. Parse and tokenize the text using spaCy, and divide into sentences.
# 2. Calculate the tf-idf matrix.
# 3. Calculate similarity scores.
# 4. Calculate TextRank: We're going to use the ´networkx´ package to run the TextRank algorithm.
#
# Let's get started!

# %%
# Importing the text the lazy way.
gatsby="In my younger and more vulnerable years my father gave me some advice that I've been turning over in my mind ever since. \"Whenever you feel like criticizing any one,\" he told me, \"just remember that all the people in this world haven't had the advantages that you've had.\" He didn't say any more but we've always been unusually communicative in a reserved way, and I understood that he meant a great deal more than that. In consequence I'm inclined to reserve all judgments, a habit that has opened up many curious natures to me and also made me the victim of not a few veteran bores. The abnormal mind is quick to detect and attach itself to this quality when it appears in a normal person, and so it came about that in college I was unjustly accused of being a politician, because I was privy to the secret griefs of wild, unknown men. Most of the confidences were unsought--frequently I have feigned sleep, preoccupation, or a hostile levity when I realized by some unmistakable sign that an intimate revelation was quivering on the horizon--for the intimate revelations of young men or at least the terms in which they express them are usually plagiaristic and marred by obvious suppressions. Reserving judgments is a matter of infinite hope. I am still a little afraid of missing something if I forget that, as my father snobbishly suggested, and I snobbishly repeat a sense of the fundamental decencies is parcelled out unequally at birth. And, after boasting this way of my tolerance, I come to the admission that it has a limit. Conduct may be founded on the hard rock or the wet marshes but after a certain point I don't care what it's founded on. When I came back from the East last autumn I felt that I wanted the world to be in uniform and at a sort of moral attention forever; I wanted no more riotous excursions with privileged glimpses into the human heart. Only Gatsby, the man who gives his name to this book, was exempt from my reaction--Gatsby who represented everything for which I have an unaffected scorn. If personality is an unbroken series of successful gestures, then there was something gorgeous about him, some heightened sensitivity to the promises of life, as if he were related to one of those intricate machines that register earthquakes ten thousand miles away. This responsiveness had nothing to do with that flabby impressionability which is dignified under the name of the \"creative temperament\"--it was an extraordinary gift for hope, a romantic readiness such as I have never found in any other person and which it is not likely I shall ever find again. No--Gatsby turned out all right at the end; it is what preyed on Gatsby, what foul dust floated in the wake of his dreams that temporarily closed out my interest in the abortive sorrows and short-winded elations of men."

# We want to use the standard english-language parser.
parser = spacy.load('en')

# Parsing Gatsby.
gatsby = parser(gatsby)

# Dividing the text into sentences and storing them as a list of strings.
sentences=[]
for span in gatsby.sents:
    # go from the start to the end of each span, returning each token in the sentence
    # combine each token using join()
    sent = ''.join(gatsby[i].string for i in range(span.start, span.end)).strip()
    sentences.append(sent)

# Creating the tf-idf matrix.
counter = TfidfVectorizer(lowercase=False, 
                          stop_words=None,
                          ngram_range=(1, 1), 
                          analyzer=u'word', 
                          max_df=.5, 
                          min_df=1,
                          max_features=None, 
                          vocabulary=None, 
                          binary=False)

#Applying the vectorizer
data_counts=counter.fit_transform(sentences)

# %% [markdown]
# # Similarity
#
# So far, this is all (hopefully) familiar: We've done text parsing and the tf-idf calculation before.  We should now have sentences represented as vectors, with each word having a score based on how often it occurs in the sentence divided by how often it occurs in the whole text.
#
# Now let's calculate the similarity scores for the sentences and apply the TextRank algorithm.  Because TextRank is based on Google's PageRank algorithm, the function is called 'pagerank'.  The hyperparameters are the damping parameter ´alpha´ and the convergence parameter ´tol´.

# %%
# Calculating similarity
similarity = data_counts * data_counts.T

# Identifying the sentence with the highest rank.
nx_graph = nx.from_scipy_sparse_matrix(similarity)
ranks=nx.pagerank(nx_graph, alpha=.85, tol=.00000001)

ranked = sorted(((ranks[i],s) for i,s in enumerate(sentences)),
                reverse=True)
print(ranked[0])
# Out:
# (0.0639701861589625, 'The abnormal mind is quick to detect and attach itself to this quality when it appears in a normal person, and so it came about that in college I was unjustly accused of being a politician, because I was privy to the secret griefs of wild, unknown men.')

# %% [markdown]
# (This is just me, exploring some of the attributes available...)

# %%
dir(gatsby[0])
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_extension',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
#  'is_punct',
#  'is_quote',
#  'is_right_punct',
#  'is_sent_start',
#  'is_space',
#  'is_stop',
#  'is_title',
#  'is_upper',
#  'lang',
#  'lang_',
#  'left_edge',
#  'lefts',
#  'lemma',
#  'lemma_',
#  'lex_id',
#  'like_email',
#  'like_num',
#  'like_url',
#  'lower',
#  'lower_',
#  'morph',
#  'n_lefts',
#  'n_rights',
#  'nbor',
#  'norm',
#  'norm_',
#  'orth',
#  'orth_',
#  'pos',
#  'pos_',
#  'prefix',
#  'prefix_',
#  'prob',
#  'rank',
#  'remove_extension',
#  'right_edge',
#  'rights',
#  'sent',
#  'sent_start',
#  'sentiment',
#  'set_extension',
#  'shape',
#  'shape_',
#  'similarity',
#  'string',
#  'subtree',
#  'suffix',
#  'suffix_',
#  'tag',
#  'tag_',
#  'tensor',
#  'text',
#  'text_with_ws',
#  'vector',
#  'vector_norm',
#  'vocab',
#  'whitespace_']

# %%
for word in gatsby:
    print(word,word.pos_,word.lemma_,word.is_stop,word.is_sent_start,word.whitespace_,)
# Out:
# In ADP in True True
# my PRON -PRON- True None
# younger ADJ young False None
# and CCONJ and True None
# more ADV more True None
# vulnerable ADJ vulnerable False None
# years NOUN year False None
# my PRON -PRON- True None
# father NOUN father False None
# gave VERB give False None
# me PRON -PRON- True None
# some DET some True None
# advice NOUN advice False None
# that PRON that True None
# I PRON -PRON- True None
# 've AUX have True None
# been AUX be True None
# turning VERB turn False None
# over ADP over True None
# in ADP in True None
# my PRON -PRON- True None
# mind NOUN mind False None
# ever ADV ever True None
# since ADV since True None
# . PUNCT . False None
# " PUNCT " False True
# Whenever ADV whenever True None
# you PRON -PRON- True None
# feel VERB feel False None
# like SCONJ like False None
# criticizing VERB criticize False None
# any DET any True None
# one NUM one True None
# , PUNCT , False None
# " PUNCT " False None
# he PRON -PRON- True None
# told VERB tell False None
# me PRON -PRON- True None
# , PUNCT , False None
# " PUNCT " False None
# just ADV just True None
# remember VERB remember False None
# that SCONJ that True None
# all DET all True None
# the DET the True None
# people NOUN people False None
# in ADP in True None
# this DET this True None
# world NOUN world False None
# have AUX have True None
# n't PART not True None
# had VERB have True None
# the DET the True None
# advantages NOUN advantage False None
# that SCONJ that True None
# you PRON -PRON- True None
# 've AUX have True None
# had VERB have True None
# . PUNCT . False None
# " PUNCT " False True
# He PRON -PRON- True None
# did AUX do True None
# n't PART not True None
# say VERB say True None
# any DET any True None
# more ADV more True None
# but CCONJ but True True
# we PRON -PRON- True None
# 've AUX have True None
# always ADV always True None
# been AUX be True None
# unusually ADV unusually False None
# communicative ADJ communicative False None
# in ADP in True None
# a DET a True None
# reserved ADJ reserved False None
# way NOUN way False None
# , PUNCT , False None
# and CCONJ and True None
# I PRON -PRON- True True
# understood VERB understand False None
# that SCONJ that True None
# he PRON -PRON- True None
# meant VERB mean False None
# a DET a True None
# great ADJ great False None
# deal NOUN deal False None
# more ADJ more True None
# than SCONJ than True None
# that DET that True None
# . PUNCT . False None
# In ADP in True True
# consequence NOUN consequence False None
# I PRON -PRON- True None
# 'm AUX be True None
# inclined ADJ inclined False None
# to PART to True None
# reserve VERB reserve False None
# all DET all True None
# judgments NOUN judgment False None
# , PUNCT , False None
# a DET a True None
# habit NOUN habit False None
# that PRON that True None
# has AUX have True None
# opened VERB open False None
# up ADP up True None
# many ADJ many True None
# curious ADJ curious False None
# natures NOUN nature False None
# to ADP to True None
# me PRON -PRON- True None
# and CCONJ and True None
# also ADV also True None
# made VERB make True None
# me PRON -PRON- True None
# the DET the True None
# victim NOUN victim False None
# of ADP of True None
# not PART not True None
# a DET a True None
# few ADJ few True None
# veteran ADJ veteran False None
# bores NOUN bore False None
# . PUNCT . False None
# The DET the True True
# abnormal ADJ abnormal False None
# mind NOUN mind False None
# is AUX be True None
# quick ADJ quick False None
# to PART to True None
# detect VERB detect False None
# and CCONJ and True None
# attach VERB attach False None
# itself PRON -PRON- True None
# to ADP to True None
# this DET this True None
# quality NOUN quality False None
# when ADV when True None
# it PRON -PRON- True None
# appears VERB appear False None
# in ADP in True None
# a DET a True None
# normal ADJ normal False None
# person NOUN person False None
# , PUNCT , False None
# and CCONJ and True None
# so ADV so True None
# it PRON -PRON- True None
# came VERB come False None
# about ADP about True None
# that SCONJ that True None
# in ADP in True None
# college NOUN college False None
# I PRON -PRON- True None
# was AUX be True None
# unjustly ADV unjustly False None
# accused VERB accuse False None
# of ADP of True None
# being AUX be True None
# a DET a True None
# politician NOUN politician False None
# , PUNCT , False None
# because SCONJ because True None
# I PRON -PRON- True None
# was AUX be True None
# privy ADJ privy False None
# to ADP to True None
# the DET the True None
# secret ADJ secret False None
# griefs NOUN grief False None
# of ADP of True None
# wild ADJ wild False None
# , PUNCT , False None
# unknown ADJ unknown False None
# men NOUN man False None
# . PUNCT . False None
# Most ADJ Most True True
# of ADP of True None
# the DET the True None
# confidences NOUN confidence False None
# were AUX be True None
# unsought ADJ unsought False None
# -- PUNCT -- False None
# frequently ADV frequently False None
# I PRON -PRON- True None
# have AUX have True None
# feigned VERB feign False None
# sleep NOUN sleep False None
# , PUNCT , False None
# preoccupation NOUN preoccupation False None
# , PUNCT , False None
# or CCONJ or True None
# a DET a True None
# hostile ADJ hostile False None
# levity NOUN levity False None
# when ADV when True None
# I PRON -PRON- True None
# realized VERB realize False None
# by ADP by True None
# some DET some True None
# unmistakable ADJ unmistakable False None
# sign NOUN sign False None
# that SCONJ that True None
# an DET an True None
# intimate ADJ intimate False None
# revelation NOUN revelation False None
# was AUX be True None
# quivering VERB quiver False None
# on ADP on True None
# the DET the True None
# horizon NOUN horizon False None
# -- PUNCT -- False None
# for ADP for True None
# the DET the True None
# intimate ADJ intimate False None
# revelations NOUN revelation False None
# of ADP of True None
# young ADJ young False None
# men NOUN man False None
# or CCONJ or True None
# at ADP at True None
# least ADJ least True None
# the DET the True None
# terms NOUN term False None
# in ADP in True None
# which PRON which True None
# they PRON -PRON- True None
# express VERB express False None
# them PRON -PRON- True None
# are AUX be True None
# usually ADV usually False None
# plagiaristic ADJ plagiaristic False None
# and CCONJ and True None
# marred VERB mar False None
# by ADP by True None
# obvious ADJ obvious False None
# suppressions NOUN suppression False None
# . PUNCT . False None
# Reserving NOUN reserving False True
# judgments NOUN judgment False None
# is AUX be True None
# a DET a True None
# matter NOUN matter False None
# of ADP of True None
# infinite ADJ infinite False None
# hope NOUN hope False None
# . PUNCT . False None
# I PRON -PRON- True True
# am AUX be True None
# still ADV still True None
# a DET a True None
# little ADJ little False None
# afraid ADJ afraid False None
# of ADP of True None
# missing VERB miss False None
# something PRON something True None
# if SCONJ if True None
# I PRON -PRON- True None
# forget VERB forget False None
# that SCONJ that True None
# , PUNCT , False None
# as SCONJ as True None
# my PRON -PRON- True None
# father NOUN father False None
# snobbishly ADV snobbishly False None
# suggested VERB suggest False None
# , PUNCT , False None
# and CCONJ and True None
# I PRON -PRON- True None
# snobbishly ADV snobbishly False None
# repeat VERB repeat False None
# a DET a True None
# sense NOUN sense False None
# of ADP of True None
# the DET the True None
# fundamental ADJ fundamental False None
# decencies NOUN decency False None
# is AUX be True None
# parcelled VERB parcel False None
# out ADP out True None
# unequally ADV unequally False None
# at ADP at True None
# birth NOUN birth False None
# . PUNCT . False None
# And CCONJ and True True
# , PUNCT , False None
# after ADP after True None
# boasting VERB boast False None
# this DET this True None
# way NOUN way False None
# of ADP of True None
# my PRON -PRON- True None
# tolerance NOUN tolerance False None
# , PUNCT , False None
# I PRON -PRON- True None
# come VERB come False None
# to ADP to True None
# the DET the True None
# admission NOUN admission False None
# that SCONJ that True None
# it PRON -PRON- True None
# has AUX have True None
# a DET a True None
# limit NOUN limit False None
# . PUNCT . False None
# Conduct NOUN conduct False True
# may AUX may True None
# be AUX be True None
# founded VERB found False None
# on ADP on True None
# the DET the True None
# hard ADJ hard False None
# rock NOUN rock False None
# or CCONJ or True None
# the DET the True None
# wet ADJ wet False None
# marshes NOUN marsh False None
# but CCONJ but True None
# after ADP after True None
# a DET a True None
# certain ADJ certain False None
# point NOUN point False None
# I PRON -PRON- True None
# do AUX do True None
# n't PART not True None
# care VERB care False None
# what PRON what True None
# it PRON -PRON- True None
# 's AUX be True None
# founded VERB found False None
# on ADP on True None
# . PUNCT . False None
# When ADV when True True
# I PRON -PRON- True None
# came VERB come False None
# back ADV back True None
# from ADP from True None
# the DET the True None
# East PROPN East False None
# last ADJ last True None
# autumn NOUN autumn False None
# I PRON -PRON- True True
# felt VERB feel False None
# that SCONJ that True None
# I PRON -PRON- True None
# wanted VERB want False None
# the DET the True None
# world NOUN world False None
# to PART to True None
# be AUX be True None
# in ADP in True None
# uniform NOUN uniform False None
# and CCONJ and True None
# at ADP at True None
# a DET a True None
# sort NOUN sort False None
# of ADP of True None
# moral ADJ moral False None
# attention NOUN attention False None
# forever ADV forever False None
# ; PUNCT ; False None
# I PRON -PRON- True None
# wanted VERB want False None
# no DET no True None
# more ADV more True None
# riotous ADJ riotous False None
# excursions NOUN excursion False None
# with ADP with True None
# privileged ADJ privileged False None
# glimpses NOUN glimpse False None
# into ADP into True None
# the DET the True None
# human ADJ human False None
# heart NOUN heart False None
# . PUNCT . False None
# Only ADV only True True
# Gatsby PROPN Gatsby False None
# , PUNCT , False None
# the DET the True None
# man NOUN man False None
# who PRON who True None
# gives VERB give False None
# his PRON -PRON- True None
# name NOUN name True None
# to ADP to True None
# this DET this True None
# book NOUN book False None
# , PUNCT , False None
# was AUX be True None
# exempt ADJ exempt False None
# from ADP from True None
# my PRON -PRON- True None
# reaction NOUN reaction False None
# -- PUNCT -- False None
# Gatsby PROPN Gatsby False None
# who PRON who True None
# represented VERB represent False None
# everything PRON everything True None
# for ADP for True None
# which PRON which True None
# I PRON -PRON- True None
# have AUX have True None
# an DET an True None
# unaffected ADJ unaffected False None
# scorn NOUN scorn False None
# . PUNCT . False None
# If SCONJ if True True
# personality NOUN personality False None
# is AUX be True None
# an DET an True None
# unbroken ADJ unbroken False None
# series NOUN series False None
# of ADP of True None
# successful ADJ successful False None
# gestures NOUN gesture False None
# , PUNCT , False None
# then ADV then True None
# there PRON there True None
# was AUX be True None
# something PRON something True None
# gorgeous ADJ gorgeous False None
# about ADP about True None
# him PRON -PRON- True None
# , PUNCT , False None
# some DET some True None
# heightened VERB heighten False None
# sensitivity NOUN sensitivity False None
# to ADP to True None
# the DET the True None
# promises NOUN promise False None
# of ADP of True None
# life NOUN life False None
# , PUNCT , False None
# as SCONJ as True None
# if SCONJ if True None
# he PRON -PRON- True None
# were AUX be True None
# related VERB relate False None
# to ADP to True None
# one NUM one True None
# of ADP of True None
# those DET those True None
# intricate ADJ intricate False None
# machines NOUN machine False None
# that PRON that True None
# register VERB register False None
# earthquakes NOUN earthquake False None
# ten NUM ten True None
# thousand NUM thousand False None
# miles NOUN mile False None
# away ADV away False None
# . PUNCT . False None
# This DET this True True
# responsiveness NOUN responsiveness False None
# had AUX have True None
# nothing PRON nothing True None
# to PART to True None
# do AUX do True None
# with ADP with True None
# that DET that True None
# flabby PROPN flabby False None
# impressionability NOUN impressionability False None
# which PRON which True None
# is AUX be True None
# dignified VERB dignify False None
# under ADP under True None
# the DET the True None
# name NOUN name True None
# of ADP of True None
# the DET the True None
# " PUNCT " False None
# creative ADJ creative False None
# temperament"--it NOUN temperament"--it False None
# was AUX be True None
# an DET an True None
# extraordinary ADJ extraordinary False None
# gift NOUN gift False None
# for ADP for True None
# hope NOUN hope False None
# , PUNCT , False None
# a DET a True None
# romantic ADJ romantic False None
# readiness NOUN readiness False None
# such ADJ such True None
# as SCONJ as True None
# I PRON -PRON- True None
# have AUX have True None
# never ADV never True None
# found VERB find False None
# in ADP in True None
# any DET any True None
# other ADJ other True None
# person NOUN person False None
# and CCONJ and True None
# which PRON which True None
# it PRON -PRON- True None
# is AUX be True None
# not PART not True None
# likely ADJ likely False None
# I PRON -PRON- True None
# shall AUX shall False None
# ever ADV ever True None
# find VERB find False None
# again ADV again True None
# . PUNCT . False None
# No DET no True True
# -- PUNCT -- False True
# Gatsby PROPN Gatsby False None
# turned VERB turn False None
# out ADP out True None
# all ADV all True None
# right ADV right False None
# at ADP at True None
# the DET the True None
# end NOUN end False None
# ; PUNCT ; False None
# it PRON -PRON- True None
# is AUX be True None
# what PRON what True None
# preyed VERB prey False None
# on ADP on True None
# Gatsby PROPN Gatsby False None
# , PUNCT , False None
# what PRON what True None
# foul ADJ foul False None
# dust NOUN dust False None
# floated VERB float False None
# in ADP in True None
# the DET the True None
# wake NOUN wake False None
# of ADP of True None
# his PRON -PRON- True None
# dreams NOUN dream False None
# that PRON that True None
# temporarily ADV temporarily False None
# closed VERB close False None
# out ADP out True None
# my PRON -PRON- True None
# interest NOUN interest False None
# in ADP in True None
# the DET the True None
# abortive ADJ abortive False None
# sorrows NOUN sorrow False None
# and CCONJ and True None
# short ADV short False None
# - PUNCT - False None
# winded ADJ winded False None
# elations NOUN elation False None
# of ADP of True None
# men NOUN man False None
# . PUNCT . False None

# %% [markdown]
# How I thought I might need to extract digrams, before I realized the vectorizer has parameters to do this work:

# %%
g_len = len(gatsby)
for idx,word in enumerate(gatsby):
    if g_len == (idx+1):
        print("Done")
        break
    print(idx,g_len,word,gatsby[idx+1])
# Out:
# 0 552 In my
# 1 552 my younger
# 2 552 younger and
# 3 552 and more
# 4 552 more vulnerable
# 5 552 vulnerable years
# 6 552 years my
# 7 552 my father
# 8 552 father gave
# 9 552 gave me
# 10 552 me some
# 11 552 some advice
# 12 552 advice that
# 13 552 that I
# 14 552 I 've
# 15 552 've been
# 16 552 been turning
# 17 552 turning over
# 18 552 over in
# 19 552 in my
# 20 552 my mind
# 21 552 mind ever
# 22 552 ever since
# 23 552 since .
# 24 552 . "
# 25 552 " Whenever
# 26 552 Whenever you
# 27 552 you feel
# 28 552 feel like
# 29 552 like criticizing
# 30 552 criticizing any
# 31 552 any one
# 32 552 one ,
# 33 552 , "
# 34 552 " he
# 35 552 he told
# 36 552 told me
# 37 552 me ,
# 38 552 , "
# 39 552 " just
# 40 552 just remember
# 41 552 remember that
# 42 552 that all
# 43 552 all the
# 44 552 the people
# 45 552 people in
# 46 552 in this
# 47 552 this world
# 48 552 world have
# 49 552 have n't
# 50 552 n't had
# 51 552 had the
# 52 552 the advantages
# 53 552 advantages that
# 54 552 that you
# 55 552 you 've
# 56 552 've had
# 57 552 had .
# 58 552 . "
# 59 552 " He
# 60 552 He did
# 61 552 did n't
# 62 552 n't say
# 63 552 say any
# 64 552 any more
# 65 552 more but
# 66 552 but we
# 67 552 we 've
# 68 552 've always
# 69 552 always been
# 70 552 been unusually
# 71 552 unusually communicative
# 72 552 communicative in
# 73 552 in a
# 74 552 a reserved
# 75 552 reserved way
# 76 552 way ,
# 77 552 , and
# 78 552 and I
# 79 552 I understood
# 80 552 understood that
# 81 552 that he
# 82 552 he meant
# 83 552 meant a
# 84 552 a great
# 85 552 great deal
# 86 552 deal more
# 87 552 more than
# 88 552 than that
# 89 552 that .
# 90 552 . In
# 91 552 In consequence
# 92 552 consequence I
# 93 552 I 'm
# 94 552 'm inclined
# 95 552 inclined to
# 96 552 to reserve
# 97 552 reserve all
# 98 552 all judgments
# 99 552 judgments ,
# 100 552 , a
# 101 552 a habit
# 102 552 habit that
# 103 552 that has
# 104 552 has opened
# 105 552 opened up
# 106 552 up many
# 107 552 many curious
# 108 552 curious natures
# 109 552 natures to
# 110 552 to me
# 111 552 me and
# 112 552 and also
# 113 552 also made
# 114 552 made me
# 115 552 me the
# 116 552 the victim
# 117 552 victim of
# 118 552 of not
# 119 552 not a
# 120 552 a few
# 121 552 few veteran
# 122 552 veteran bores
# 123 552 bores .
# 124 552 . The
# 125 552 The abnormal
# 126 552 abnormal mind
# 127 552 mind is
# 128 552 is quick
# 129 552 quick to
# 130 552 to detect
# 131 552 detect and
# 132 552 and attach
# 133 552 attach itself
# 134 552 itself to
# 135 552 to this
# 136 552 this quality
# 137 552 quality when
# 138 552 when it
# 139 552 it appears
# 140 552 appears in
# 141 552 in a
# 142 552 a normal
# 143 552 normal person
# 144 552 person ,
# 145 552 , and
# 146 552 and so
# 147 552 so it
# 148 552 it came
# 149 552 came about
# 150 552 about that
# 151 552 that in
# 152 552 in college
# 153 552 college I
# 154 552 I was
# 155 552 was unjustly
# 156 552 unjustly accused
# 157 552 accused of
# 158 552 of being
# 159 552 being a
# 160 552 a politician
# 161 552 politician ,
# 162 552 , because
# 163 552 because I
# 164 552 I was
# 165 552 was privy
# 166 552 privy to
# 167 552 to the
# 168 552 the secret
# 169 552 secret griefs
# 170 552 griefs of
# 171 552 of wild
# 172 552 wild ,
# 173 552 , unknown
# 174 552 unknown men
# 175 552 men .
# 176 552 . Most
# 177 552 Most of
# 178 552 of the
# 179 552 the confidences
# 180 552 confidences were
# 181 552 were unsought
# 182 552 unsought --
# 183 552 -- frequently
# 184 552 frequently I
# 185 552 I have
# 186 552 have feigned
# 187 552 feigned sleep
# 188 552 sleep ,
# 189 552 , preoccupation
# 190 552 preoccupation ,
# 191 552 , or
# 192 552 or a
# 193 552 a hostile
# 194 552 hostile levity
# 195 552 levity when
# 196 552 when I
# 197 552 I realized
# 198 552 realized by
# 199 552 by some
# 200 552 some unmistakable
# 201 552 unmistakable sign
# 202 552 sign that
# 203 552 that an
# 204 552 an intimate
# 205 552 intimate revelation
# 206 552 revelation was
# 207 552 was quivering
# 208 552 quivering on
# 209 552 on the
# 210 552 the horizon
# 211 552 horizon --
# 212 552 -- for
# 213 552 for the
# 214 552 the intimate
# 215 552 intimate revelations
# 216 552 revelations of
# 217 552 of young
# 218 552 young men
# 219 552 men or
# 220 552 or at
# 221 552 at least
# 222 552 least the
# 223 552 the terms
# 224 552 terms in
# 225 552 in which
# 226 552 which they
# 227 552 they express
# 228 552 express them
# 229 552 them are
# 230 552 are usually
# 231 552 usually plagiaristic
# 232 552 plagiaristic and
# 233 552 and marred
# 234 552 marred by
# 235 552 by obvious
# 236 552 obvious suppressions
# 237 552 suppressions .
# 238 552 . Reserving
# 239 552 Reserving judgments
# 240 552 judgments is
# 241 552 is a
# 242 552 a matter
# 243 552 matter of
# 244 552 of infinite
# 245 552 infinite hope
# 246 552 hope .
# 247 552 . I
# 248 552 I am
# 249 552 am still
# 250 552 still a
# 251 552 a little
# 252 552 little afraid
# 253 552 afraid of
# 254 552 of missing
# 255 552 missing something
# 256 552 something if
# 257 552 if I
# 258 552 I forget
# 259 552 forget that
# 260 552 that ,
# 261 552 , as
# 262 552 as my
# 263 552 my father
# 264 552 father snobbishly
# 265 552 snobbishly suggested
# 266 552 suggested ,
# 267 552 , and
# 268 552 and I
# 269 552 I snobbishly
# 270 552 snobbishly repeat
# 271 552 repeat a
# 272 552 a sense
# 273 552 sense of
# 274 552 of the
# 275 552 the fundamental
# 276 552 fundamental decencies
# 277 552 decencies is
# 278 552 is parcelled
# 279 552 parcelled out
# 280 552 out unequally
# 281 552 unequally at
# 282 552 at birth
# 283 552 birth .
# 284 552 . And
# 285 552 And ,
# 286 552 , after
# 287 552 after boasting
# 288 552 boasting this
# 289 552 this way
# 290 552 way of
# 291 552 of my
# 292 552 my tolerance
# 293 552 tolerance ,
# 294 552 , I
# 295 552 I come
# 296 552 come to
# 297 552 to the
# 298 552 the admission
# 299 552 admission that
# 300 552 that it
# 301 552 it has
# 302 552 has a
# 303 552 a limit
# 304 552 limit .
# 305 552 . Conduct
# 306 552 Conduct may
# 307 552 may be
# 308 552 be founded
# 309 552 founded on
# 310 552 on the
# 311 552 the hard
# 312 552 hard rock
# 313 552 rock or
# 314 552 or the
# 315 552 the wet
# 316 552 wet marshes
# 317 552 marshes but
# 318 552 but after
# 319 552 after a
# 320 552 a certain
# 321 552 certain point
# 322 552 point I
# 323 552 I do
# 324 552 do n't
# 325 552 n't care
# 326 552 care what
# 327 552 what it
# 328 552 it 's
# 329 552 's founded
# 330 552 founded on
# 331 552 on .
# 332 552 . When
# 333 552 When I
# 334 552 I came
# 335 552 came back
# 336 552 back from
# 337 552 from the
# 338 552 the East
# 339 552 East last
# 340 552 last autumn
# 341 552 autumn I
# 342 552 I felt
# 343 552 felt that
# 344 552 that I
# 345 552 I wanted
# 346 552 wanted the
# 347 552 the world
# 348 552 world to
# 349 552 to be
# 350 552 be in
# 351 552 in uniform
# 352 552 uniform and
# 353 552 and at
# 354 552 at a
# 355 552 a sort
# 356 552 sort of
# 357 552 of moral
# 358 552 moral attention
# 359 552 attention forever
# 360 552 forever ;
# 361 552 ; I
# 362 552 I wanted
# 363 552 wanted no
# 364 552 no more
# 365 552 more riotous
# 366 552 riotous excursions
# 367 552 excursions with
# 368 552 with privileged
# 369 552 privileged glimpses
# 370 552 glimpses into
# 371 552 into the
# 372 552 the human
# 373 552 human heart
# 374 552 heart .
# 375 552 . Only
# 376 552 Only Gatsby
# 377 552 Gatsby ,
# 378 552 , the
# 379 552 the man
# 380 552 man who
# 381 552 who gives
# 382 552 gives his
# 383 552 his name
# 384 552 name to
# 385 552 to this
# 386 552 this book
# 387 552 book ,
# 388 552 , was
# 389 552 was exempt
# 390 552 exempt from
# 391 552 from my
# 392 552 my reaction
# 393 552 reaction --
# 394 552 -- Gatsby
# 395 552 Gatsby who
# 396 552 who represented
# 397 552 represented everything
# 398 552 everything for
# 399 552 for which
# 400 552 which I
# 401 552 I have
# 402 552 have an
# 403 552 an unaffected
# 404 552 unaffected scorn
# 405 552 scorn .
# 406 552 . If
# 407 552 If personality
# 408 552 personality is
# 409 552 is an
# 410 552 an unbroken
# 411 552 unbroken series
# 412 552 series of
# 413 552 of successful
# 414 552 successful gestures
# 415 552 gestures ,
# 416 552 , then
# 417 552 then there
# 418 552 there was
# 419 552 was something
# 420 552 something gorgeous
# 421 552 gorgeous about
# 422 552 about him
# 423 552 him ,
# 424 552 , some
# 425 552 some heightened
# 426 552 heightened sensitivity
# 427 552 sensitivity to
# 428 552 to the
# 429 552 the promises
# 430 552 promises of
# 431 552 of life
# 432 552 life ,
# 433 552 , as
# 434 552 as if
# 435 552 if he
# 436 552 he were
# 437 552 were related
# 438 552 related to
# 439 552 to one
# 440 552 one of
# 441 552 of those
# 442 552 those intricate
# 443 552 intricate machines
# 444 552 machines that
# 445 552 that register
# 446 552 register earthquakes
# 447 552 earthquakes ten
# 448 552 ten thousand
# 449 552 thousand miles
# 450 552 miles away
# 451 552 away .
# 452 552 . This
# 453 552 This responsiveness
# 454 552 responsiveness had
# 455 552 had nothing
# 456 552 nothing to
# 457 552 to do
# 458 552 do with
# 459 552 with that
# 460 552 that flabby
# 461 552 flabby impressionability
# 462 552 impressionability which
# 463 552 which is
# 464 552 is dignified
# 465 552 dignified under
# 466 552 under the
# 467 552 the name
# 468 552 name of
# 469 552 of the
# 470 552 the "
# 471 552 " creative
# 472 552 creative temperament"--it
# 473 552 temperament"--it was
# 474 552 was an
# 475 552 an extraordinary
# 476 552 extraordinary gift
# 477 552 gift for
# 478 552 for hope
# 479 552 hope ,
# 480 552 , a
# 481 552 a romantic
# 482 552 romantic readiness
# 483 552 readiness such
# 484 552 such as
# 485 552 as I
# 486 552 I have
# 487 552 have never
# 488 552 never found
# 489 552 found in
# 490 552 in any
# 491 552 any other
# 492 552 other person
# 493 552 person and
# 494 552 and which
# 495 552 which it
# 496 552 it is
# 497 552 is not
# 498 552 not likely
# 499 552 likely I
# 500 552 I shall
# 501 552 shall ever
# 502 552 ever find
# 503 552 find again
# 504 552 again .
# 505 552 . No
# 506 552 No --
# 507 552 -- Gatsby
# 508 552 Gatsby turned
# 509 552 turned out
# 510 552 out all
# 511 552 all right
# 512 552 right at
# 513 552 at the
# 514 552 the end
# 515 552 end ;
# 516 552 ; it
# 517 552 it is
# 518 552 is what
# 519 552 what preyed
# 520 552 preyed on
# 521 552 on Gatsby
# 522 552 Gatsby ,
# 523 552 , what
# 524 552 what foul
# 525 552 foul dust
# 526 552 dust floated
# 527 552 floated in
# 528 552 in the
# 529 552 the wake
# 530 552 wake of
# 531 552 of his
# 532 552 his dreams
# 533 552 dreams that
# 534 552 that temporarily
# 535 552 temporarily closed
# 536 552 closed out
# 537 552 out my
# 538 552 my interest
# 539 552 interest in
# 540 552 in the
# 541 552 the abortive
# 542 552 abortive sorrows
# 543 552 sorrows and
# 544 552 and short
# 545 552 short -
# 546 552 - winded
# 547 552 winded elations
# 548 552 elations of
# 549 552 of men
# 550 552 men .
# Done

# %% [markdown]
# Since a lot of Gatsby is about the narrator acting as the observer of other peoples' sordid secrets, this seems pretty good.  Now, let's extract some keywords.
#
# # Keyword summarization
#
# 1) Parse and tokenize text (already done).
# 2) Filter out stopwords, choose only nouns and adjectives.
# 3) Calculate the neighbors of words (we'll use a window of 4).
# 4) Run TextRank on the neighbor matrix.

# %%
# Removing stop words and punctuation, then getting a list of all unique words in the text
gatsby_filt = [word for word in gatsby if word.is_stop==False and (word.pos_=='NOUN' or word.pos_=='ADJ')]
words=set(gatsby_filt)

#Creating a grid indicating whether words are within 4 places of the target word
adjacency=pd.DataFrame(columns=words,index=words,data=0)

#Iterating through each word in the text and indicating which of the unique words are its neighbors
for i,word in enumerate(gatsby):
    # Checking if any of the word's next four neighbors are in the word list 
    if any([word == item for item in gatsby_filt]):
        # Making sure to stop at the end of the string, even if there are less than four words left after the target.
        end=max(0,len(gatsby)-(len(gatsby)-(i+5)))
        # The potential neighbors.
        nextwords=gatsby[i+1:end]
        # Filtering the neighbors to select only those in the word list
        inset=[x in gatsby_filt for x in nextwords]
        neighbors=[nextwords[i] for i in range(len(nextwords)) if inset[i]]
        # Adding 1 to the adjacency matrix for neighbors of the target word
        if neighbors:
            adjacency.loc[word,neighbors]=adjacency.loc[word,neighbors]+1

print('done!')
# Out:
# done!

# %%
# Running TextRank
#nx_words = nx.from_numpy_matrix(adjacency.as_matrix()) #<--gave me a FutureWarning and suggested .values. So...
nx_words = nx.from_numpy_matrix(adjacency.values)
ranks=nx.pagerank(nx_words, alpha=.85, tol=.00000001)

# Identifying the five most highly ranked keywords
ranked = sorted(((ranks[i],s) for i,s in enumerate(words)),
                reverse=True)
print(ranked[:5])
# Out:
# [(0.012415518587086127, promises), (0.012415518587086127, exempt), (0.012333160533862523, glimpses), (0.012082343425981395, intimate), (0.012054574145630725, earthquakes)]

# %% [markdown]
# These results are less impressive.  'Hope', 'promises', and 'glimpses' certainly fit the elegiac, on-the-outside-looking-in tone of the book, but 'exempt' and 'world' are pretty generic.  TextRank may perform better on a larger text sample.
#
# # Drill
#
# It is also possible that keyword phrases will work better.  Modifiy the keyword extraction code to extract two-word phrases (digrams) rather than single words.  Then try it with trigrams.  You will probably want to broaden the window that defines 'neighbors.'  Try a few different modifications, and write up your observations in your notebook.  Discuss with your mentor.

# %% [markdown]
# >__Each of the word sets could then operate as its own feature.__ Ngrams can be used to create term-document matrices (though it would now be ngram-document matrices), or used in topic modeling. In addition, ngrams are useful for text prediction as they can be used to determine what words are most likely to follow in a sentence, phrase, or search query.
#
# >For a sentence with X words, there will be X-(N-1) Ngrams. 2-gram phrases are also called ‘bigrams,’ 3-gram phrases are called ‘trigrams,’ etc.

# %% [markdown]
# ### Starting over with bigrams:

# %%
# Utility function to clean text.
import re
def text_cleaner(text):
    
    # Visual inspection shows spaCy does not recognize the double dash '--'.
    # Better get rid of it now!
    text = re.sub(r'--',' ',text)
# Get rid of extra whitespace.
    text = ' '.join(text.split())    
    return text

# %%
# Importing the text the lazy way.
gatsby="In my younger and more vulnerable years my father gave me some advice that I've been turning over in my mind ever since. \"Whenever you feel like criticizing any one,\" he told me, \"just remember that all the people in this world haven't had the advantages that you've had.\" He didn't say any more but we've always been unusually communicative in a reserved way, and I understood that he meant a great deal more than that. In consequence I'm inclined to reserve all judgments, a habit that has opened up many curious natures to me and also made me the victim of not a few veteran bores. The abnormal mind is quick to detect and attach itself to this quality when it appears in a normal person, and so it came about that in college I was unjustly accused of being a politician, because I was privy to the secret griefs of wild, unknown men. Most of the confidences were unsought--frequently I have feigned sleep, preoccupation, or a hostile levity when I realized by some unmistakable sign that an intimate revelation was quivering on the horizon--for the intimate revelations of young men or at least the terms in which they express them are usually plagiaristic and marred by obvious suppressions. Reserving judgments is a matter of infinite hope. I am still a little afraid of missing something if I forget that, as my father snobbishly suggested, and I snobbishly repeat a sense of the fundamental decencies is parcelled out unequally at birth. And, after boasting this way of my tolerance, I come to the admission that it has a limit. Conduct may be founded on the hard rock or the wet marshes but after a certain point I don't care what it's founded on. When I came back from the East last autumn I felt that I wanted the world to be in uniform and at a sort of moral attention forever; I wanted no more riotous excursions with privileged glimpses into the human heart. Only Gatsby, the man who gives his name to this book, was exempt from my reaction--Gatsby who represented everything for which I have an unaffected scorn. If personality is an unbroken series of successful gestures, then there was something gorgeous about him, some heightened sensitivity to the promises of life, as if he were related to one of those intricate machines that register earthquakes ten thousand miles away. This responsiveness had nothing to do with that flabby impressionability which is dignified under the name of the \"creative temperament\"--it was an extraordinary gift for hope, a romantic readiness such as I have never found in any other person and which it is not likely I shall ever find again. No--Gatsby turned out all right at the end; it is what preyed on Gatsby, what foul dust floated in the wake of his dreams that temporarily closed out my interest in the abortive sorrows and short-winded elations of men."

gatsby = text_cleaner(gatsby)

# We want to use the standard english-language parser.
parser = spacy.load('en')

# Parsing Gatsby.
gatsby = parser(gatsby)

# Dividing the text into sentences and storing them as a list of strings.
sentences=[]
for span in gatsby.sents:
    # go from the start to the end of each span, returning each token in the sentence
    # combine each token using join()
    sent = ''.join(gatsby[i].string for i in range(span.start, span.end)).strip()
    sentences.append(sent)

# Creating the tf-idf matrix.
counter = TfidfVectorizer(lowercase=False, 
                          stop_words=None,
                          ngram_range=(2,2), #<--Build bigrams instead of single words
                          analyzer=u'word', 
                          max_df=.5, 
                          min_df=1,
                          max_features=None, 
                          vocabulary=None, 
                          binary=False)

#Applying the vectorizer
data_counts=counter.fit_transform(sentences)

# %% [markdown]
# gatsby_nouns_adjectives = []
# for word in gatsby:
#     if word.is_stop==False and \
#        word.is_punct==False and \
#        (word.pos_=='NOUN' or word.pos_=='ADJ'):
#         gatsby_nouns_adjectives.append(word)
# g_len = len(gatsby_nouns_adjectives)
# gatsby_bigrams = []
#
# for idx,word in enumerate(gatsby_nouns_adjectives):
#     if g_len == (idx+1):
#         print("Done")
#         break
#     gatsby_bigrams.append('{}_{}'.format(word,gatsby_nouns_adjectives[idx+1]))
#     print(idx,g_len,word,gatsby[idx+1])

# %%
gatsby_bigrams = list(counter.vocabulary_.keys())

# %%
# This stuff all stays the same:

# Calculating similarity
similarity = data_counts * data_counts.T

# Identifying the sentence with the highest rank.
nx_graph = nx.from_scipy_sparse_matrix(similarity)
ranks=nx.pagerank(nx_graph, alpha=.85, tol=.00000001)

ranked = sorted(((ranks[i],s) for i,s in enumerate(sentences)),
                reverse=True)
print(ranked[0])
# Out:
# (0.05045297153830663, 'The abnormal mind is quick to detect and attach itself to this quality when it appears in a normal person, and so it came about that in college I was unjustly accused of being a politician, because I was privy to the secret griefs of wild, unknown men.')

# %%
# Getting a list of all unique bigrams in the text
words=set(gatsby_bigrams)

#Creating a grid indicating whether words are within 4 places of the target word
adjacency=pd.DataFrame(columns=words,index=words,data=0)

#Iterating through each word in the text and indicating which of the unique words are its neighbors
for i,word in enumerate(gatsby_bigrams):
    # Checking if any of the word's next four neighbors are in the word list 
    if any([word == item for item in gatsby_bigrams]):
        # Making sure to stop at the end of the string, even if there are less than four words left after the target.
        end=max(0,len(gatsby_bigrams)-(len(gatsby_bigrams)-(i+5)))
        # The potential neighbors.
        nextwords=gatsby_bigrams[i+1:end]
        # Filtering the neighbors to select only those in the word list
        inset=[x in gatsby_bigrams for x in nextwords]
        neighbors=[nextwords[i] for i in range(len(nextwords)) if inset[i]]
        # Adding 1 to the adjacency matrix for neighbors of the target word
        if neighbors:
            adjacency.loc[word,neighbors]=adjacency.loc[word,neighbors]+1

print('done!')
# Out:
# done!

# %%
adjacency
# Out:
#                          unusually communicative  he meant  of not  \
# unusually communicative                        0         0       0
# he meant                                       0         0       0
# of not                                         0         0       0
# his dreams                                     0         0       0
# turning over                                   0         0       0
# ...                                          ...       ...     ...
# as my                                          0         0       0
# Conduct may                                    0         0       0
# unbroken series                                0         0       0
# horizon for                                    0         0       0
# at sort                                        0         0       0
#
#                          his dreams  turning over  it has  the secret  \
# unusually communicative           0             0       0           0
# he meant                          0             0       0           0
# of not                            0             0       0           0
# his dreams                        0             0       0           0
# turning over                      0             0       0           0
# ...                             ...           ...     ...         ...
# as my                             0             0       0           0
# Conduct may                       0             0       0           0
# unbroken series                   0             0       0           0
# horizon for                       0             0       0           0
# at sort                           0             0       0           0
#
#                          as have  wild unknown  shall ever  ...  the hard  \
# unusually communicative        0             0           0  ...         0
# he meant                       0             0           0  ...         0
# of not                         0             0           0  ...         0
# his dreams                     0             0           0  ...         0
# turning over                   0             0           0  ...         0
# ...                          ...           ...         ...  ...       ...
# as my                          0             0           0  ...         0
# Conduct may                    0             0           0  ...         1
# unbroken series                0             0           0  ...         0
# horizon for                    0             0           0  ...         0
# at sort                        0             0           0  ...         0
#
#                          No Gatsby  or the  romantic readiness  sense of  \
# unusually communicative          0       0                   0         0
# he meant                         0       0                   0         0
# of not                           0       0                   0         0
# his dreams                       0       0                   0         0
# turning over                     0       0                   0         0
# ...                            ...     ...                 ...       ...
# as my                            0       0                   0         0
# Conduct may                      0       0                   0         0
# unbroken series                  0       0                   0         0
# horizon for                      0       0                   0         0
# at sort                          0       0                   0         0
#
#                          as my  Conduct may  unbroken series  horizon for  \
# unusually communicative      0            0                0            0
# he meant                     0            0                0            0
# of not                       0            0                0            0
# his dreams                   0            0                0            0
# turning over                 0            0                0            0
# ...                        ...          ...              ...          ...
# as my                        0            0                0            0
# Conduct may                  0            0                0            0
# unbroken series              0            0                0            0
# horizon for                  0            0                0            0
# at sort                      0            0                0            0
#
#                          at sort
# unusually communicative        0
# he meant                       0
# of not                         0
# his dreams                     0
# turning over                   0
# ...                          ...
# as my                          0
# Conduct may                    0
# unbroken series                0
# horizon for                    0
# at sort                        0
#
# [437 rows x 437 columns]

# %%
gatsby_bigrams
# Out:
# ['In my',
#  'my younger',
#  'younger and',
#  'and more',
#  'more vulnerable',
#  'vulnerable years',
#  'years my',
#  'my father',
#  'father gave',
#  'gave me',
#  'me some',
#  'some advice',
#  'advice that',
#  'that ve',
#  've been',
#  'been turning',
#  'turning over',
#  'over in',
#  'in my',
#  'my mind',
#  'mind ever',
#  'ever since',
#  'Whenever you',
#  'you feel',
#  'feel like',
#  'like criticizing',
#  'criticizing any',
#  'any one',
#  'one he',
#  'he told',
#  'told me',
#  'me just',
#  'just remember',
#  'remember that',
#  'that all',
#  'all the',
#  'the people',
#  'people in',
#  'in this',
#  'this world',
#  'world haven',
#  'haven had',
#  'had the',
#  'the advantages',
#  'advantages that',
#  'that you',
#  'you ve',
#  've had',
#  'He didn',
#  'didn say',
#  'say any',
#  'any more',
#  'but we',
#  'we ve',
#  've always',
#  'always been',
#  'been unusually',
#  'unusually communicative',
#  'communicative in',
#  'in reserved',
#  'reserved way',
#  'way and',
#  'understood that',
#  'that he',
#  'he meant',
#  'meant great',
#  'great deal',
#  'deal more',
#  'more than',
#  'than that',
#  'In consequence',
#  'consequence inclined',
#  'inclined to',
#  'to reserve',
#  'reserve all',
#  'all judgments',
#  'judgments habit',
#  'habit that',
#  'that has',
#  'has opened',
#  'opened up',
#  'up many',
#  'many curious',
#  'curious natures',
#  'natures to',
#  'to me',
#  'me and',
#  'and also',
#  'also made',
#  'made me',
#  'me the',
#  'the victim',
#  'victim of',
#  'of not',
#  'not few',
#  'few veteran',
#  'veteran bores',
#  'The abnormal',
#  'abnormal mind',
#  'mind is',
#  'is quick',
#  'quick to',
#  'to detect',
#  'detect and',
#  'and attach',
#  'attach itself',
#  'itself to',
#  'to this',
#  'this quality',
#  'quality when',
#  'when it',
#  'it appears',
#  'appears in',
#  'in normal',
#  'normal person',
#  'person and',
#  'and so',
#  'so it',
#  'it came',
#  'came about',
#  'about that',
#  'that in',
#  'in college',
#  'college was',
#  'was unjustly',
#  'unjustly accused',
#  'accused of',
#  'of being',
#  'being politician',
#  'politician because',
#  'because was',
#  'was privy',
#  'privy to',
#  'to the',
#  'the secret',
#  'secret griefs',
#  'griefs of',
#  'of wild',
#  'wild unknown',
#  'unknown men',
#  'Most of',
#  'of the',
#  'the confidences',
#  'confidences were',
#  'were unsought',
#  'frequently have',
#  'have feigned',
#  'feigned sleep',
#  'sleep preoccupation',
#  'preoccupation or',
#  'or hostile',
#  'hostile levity',
#  'levity when',
#  'when realized',
#  'realized by',
#  'by some',
#  'some unmistakable',
#  'unmistakable sign',
#  'sign that',
#  'that an',
#  'an intimate',
#  'intimate revelation',
#  'revelation was',
#  'was quivering',
#  'quivering on',
#  'on the',
#  'the horizon',
#  'horizon for',
#  'for the',
#  'the intimate',
#  'intimate revelations',
#  'revelations of',
#  'of young',
#  'young men',
#  'men or',
#  'or at',
#  'at least',
#  'least the',
#  'the terms',
#  'terms in',
#  'in which',
#  'which they',
#  'they express',
#  'express them',
#  'them are',
#  'are usually',
#  'usually plagiaristic',
#  'plagiaristic and',
#  'and marred',
#  'marred by',
#  'by obvious',
#  'obvious suppressions',
#  'Reserving judgments',
#  'judgments is',
#  'is matter',
#  'matter of',
#  'of infinite',
#  'infinite hope',
#  'am still',
#  'still little',
#  'little afraid',
#  'afraid of',
#  'of missing',
#  'missing something',
#  'something if',
#  'if forget',
#  'forget that',
#  'that as',
#  'as my',
#  'father snobbishly',
#  'snobbishly suggested',
#  'suggested and',
#  'and snobbishly',
#  'snobbishly repeat',
#  'repeat sense',
#  'sense of',
#  'the fundamental',
#  'fundamental decencies',
#  'decencies is',
#  'is parcelled',
#  'parcelled out',
#  'out unequally',
#  'unequally at',
#  'at birth',
#  'And after',
#  'after boasting',
#  'boasting this',
#  'this way',
#  'way of',
#  'of my',
#  'my tolerance',
#  'tolerance come',
#  'come to',
#  'the admission',
#  'admission that',
#  'that it',
#  'it has',
#  'has limit',
#  'Conduct may',
#  'may be',
#  'be founded',
#  'founded on',
#  'the hard',
#  'hard rock',
#  'rock or',
#  'or the',
#  'the wet',
#  'wet marshes',
#  'marshes but',
#  'but after',
#  'after certain',
#  'certain point',
#  'point don',
#  'don care',
#  'care what',
#  'what it',
#  'it founded',
#  'When came',
#  'came back',
#  'back from',
#  'from the',
#  'the East',
#  'East last',
#  'last autumn',
#  'felt that',
#  'that wanted',
#  'wanted the',
#  'the world',
#  'world to',
#  'to be',
#  'be in',
#  'in uniform',
#  'uniform and',
#  'and at',
#  'at sort',
#  'sort of',
#  'of moral',
#  'moral attention',
#  'attention forever',
#  'forever wanted',
#  'wanted no',
#  'no more',
#  'more riotous',
#  'riotous excursions',
#  'excursions with',
#  'with privileged',
#  'privileged glimpses',
#  'glimpses into',
#  'into the',
#  'the human',
#  'human heart',
#  'Only Gatsby',
#  'Gatsby the',
#  'the man',
#  'man who',
#  'who gives',
#  'gives his',
#  'his name',
#  'name to',
#  'this book',
#  'book was',
#  'was exempt',
#  'exempt from',
#  'from my',
#  'my reaction',
#  'reaction Gatsby',
#  'Gatsby who',
#  'who represented',
#  'represented everything',
#  'everything for',
#  'for which',
#  'which have',
#  'have an',
#  'an unaffected',
#  'unaffected scorn',
#  'If personality',
#  'personality is',
#  'is an',
#  'an unbroken',
#  'unbroken series',
#  'series of',
#  'of successful',
#  'successful gestures',
#  'gestures then',
#  'then there',
#  'there was',
#  'was something',
#  'something gorgeous',
#  'gorgeous about',
#  'about him',
#  'him some',
#  'some heightened',
#  'heightened sensitivity',
#  'sensitivity to',
#  'the promises',
#  'promises of',
#  'of life',
#  'life as',
#  'as if',
#  'if he',
#  'he were',
#  'were related',
#  'related to',
#  'to one',
#  'one of',
#  'of those',
#  'those intricate',
#  'intricate machines',
#  'machines that',
#  'that register',
#  'register earthquakes',
#  'earthquakes ten',
#  'ten thousand',
#  'thousand miles',
#  'miles away',
#  'This responsiveness',
#  'responsiveness had',
#  'had nothing',
#  'nothing to',
#  'to do',
#  'do with',
#  'with that',
#  'that flabby',
#  'flabby impressionability',
#  'impressionability which',
#  'which is',
#  'is dignified',
#  'dignified under',
#  'under the',
#  'the name',
#  'name of',
#  'the creative',
#  'creative temperament',
#  'temperament it',
#  'it was',
#  'was an',
#  'an extraordinary',
#  'extraordinary gift',
#  'gift for',
#  'for hope',
#  'hope romantic',
#  'romantic readiness',
#  'readiness such',
#  'such as',
#  'as have',
#  'have never',
#  'never found',
#  'found in',
#  'in any',
#  'any other',
#  'other person',
#  'and which',
#  'it is',
#  'is not',
#  'not likely',
#  'likely shall',
#  'shall ever',
#  'ever find',
#  'find again',
#  'No Gatsby',
#  'Gatsby turned',
#  'turned out',
#  'out all',
#  'all right',
#  'right at',
#  'at the',
#  'the end',
#  'end it',
#  'is what',
#  'what preyed',
#  'preyed on',
#  'on Gatsby',
#  'Gatsby what',
#  'what foul',
#  'foul dust',
#  'dust floated',
#  'floated in',
#  'in the',
#  'the wake',
#  'wake of',
#  'of his',
#  'his dreams',
#  'dreams that',
#  'that temporarily',
#  'temporarily closed',
#  'closed out',
#  'out my',
#  'my interest',
#  'interest in',
#  'the abortive',
#  'abortive sorrows',
#  'sorrows and',
#  'and short',
#  'short winded',
#  'winded elations',
#  'elations of',
#  'of men']

# %%
# Running TextRank
#nx_words = nx.from_numpy_matrix(adjacency.as_matrix()) #<--gave me a FutureWarning and suggested .values. So...
nx_words = nx.from_numpy_matrix(adjacency.values)
ranks=nx.pagerank(nx_words, alpha=.85, tol=.00000001)

# Identifying the five most highly ranked keywords
ranked = sorted(((ranks[i],s) for i,s in enumerate(words)),
                reverse=True)
print(ranked[:5])
# Out:
# [(0.002580891935930987, 'more vulnerable'), (0.002580891935930987, 'and short'), (0.0025240089764954807, 'vulnerable years'), (0.0025240089764954807, 'sorrows and'), (0.0024789984790138707, 'years my')]

# %% [markdown]
# ### And now, trigrams?

# %%
# Importing the text the lazy way.
gatsby="In my younger and more vulnerable years my father gave me some advice that I've been turning over in my mind ever since. \"Whenever you feel like criticizing any one,\" he told me, \"just remember that all the people in this world haven't had the advantages that you've had.\" He didn't say any more but we've always been unusually communicative in a reserved way, and I understood that he meant a great deal more than that. In consequence I'm inclined to reserve all judgments, a habit that has opened up many curious natures to me and also made me the victim of not a few veteran bores. The abnormal mind is quick to detect and attach itself to this quality when it appears in a normal person, and so it came about that in college I was unjustly accused of being a politician, because I was privy to the secret griefs of wild, unknown men. Most of the confidences were unsought--frequently I have feigned sleep, preoccupation, or a hostile levity when I realized by some unmistakable sign that an intimate revelation was quivering on the horizon--for the intimate revelations of young men or at least the terms in which they express them are usually plagiaristic and marred by obvious suppressions. Reserving judgments is a matter of infinite hope. I am still a little afraid of missing something if I forget that, as my father snobbishly suggested, and I snobbishly repeat a sense of the fundamental decencies is parcelled out unequally at birth. And, after boasting this way of my tolerance, I come to the admission that it has a limit. Conduct may be founded on the hard rock or the wet marshes but after a certain point I don't care what it's founded on. When I came back from the East last autumn I felt that I wanted the world to be in uniform and at a sort of moral attention forever; I wanted no more riotous excursions with privileged glimpses into the human heart. Only Gatsby, the man who gives his name to this book, was exempt from my reaction--Gatsby who represented everything for which I have an unaffected scorn. If personality is an unbroken series of successful gestures, then there was something gorgeous about him, some heightened sensitivity to the promises of life, as if he were related to one of those intricate machines that register earthquakes ten thousand miles away. This responsiveness had nothing to do with that flabby impressionability which is dignified under the name of the \"creative temperament\"--it was an extraordinary gift for hope, a romantic readiness such as I have never found in any other person and which it is not likely I shall ever find again. No--Gatsby turned out all right at the end; it is what preyed on Gatsby, what foul dust floated in the wake of his dreams that temporarily closed out my interest in the abortive sorrows and short-winded elations of men."

gatsby = text_cleaner(gatsby)

# We want to use the standard english-language parser.
parser = spacy.load('en')

# Parsing Gatsby.
gatsby = parser(gatsby)

# Dividing the text into sentences and storing them as a list of strings.
sentences=[]
for span in gatsby.sents:
    # go from the start to the end of each span, returning each token in the sentence
    # combine each token using join()
    sent = ''.join(gatsby[i].string for i in range(span.start, span.end)).strip()
    sentences.append(sent)

# Creating the tf-idf matrix.
counter = TfidfVectorizer(lowercase=False, 
                          stop_words=None,
                          ngram_range=(3,3), #<--Build bigrams instead of single words
                          analyzer=u'word', 
                          max_df=.5, 
                          min_df=1,
                          max_features=None, 
                          vocabulary=None, 
                          binary=False)

#Applying the vectorizer
data_counts=counter.fit_transform(sentences)

# %%
gatsby_trigrams = list(counter.vocabulary_.keys())

# %%
# This stuff all stays the same:

# Calculating similarity
similarity = data_counts * data_counts.T

# Identifying the sentence with the highest rank.
nx_graph = nx.from_scipy_sparse_matrix(similarity)
ranks=nx.pagerank(nx_graph, alpha=.85, tol=.00000001)

ranked = sorted(((ranks[i],s) for i,s in enumerate(sentences)),
                reverse=True)
print(ranked[0])
# Out:
# (0.05, 'it is not likely I shall ever find again.')

# %%
# Getting a list of all unique bigrams in the text
words=set(gatsby_trigrams)

#Creating a grid indicating whether words are within 4 places of the target word
adjacency=pd.DataFrame(columns=words,index=words,data=0)

#Iterating through each word in the text and indicating which of the unique words are its neighbors
for i,word in enumerate(gatsby_trigrams):
    # Checking if any of the word's next four neighbors are in the word list 
    if any([word == item for item in gatsby_trigrams]):
        # Making sure to stop at the end of the string, even if there are less than four words left after the target.
        end=max(0,len(gatsby_trigrams)-(len(gatsby_trigrams)-(i+5)))
        # The potential neighbors.
        nextwords=gatsby_trigrams[i+1:end]
        # Filtering the neighbors to select only those in the word list
        inset=[x in gatsby_trigrams for x in nextwords]
        neighbors=[nextwords[i] for i in range(len(nextwords)) if inset[i]]
        # Adding 1 to the adjacency matrix for neighbors of the target word
        if neighbors:
            adjacency.loc[word,neighbors]=adjacency.loc[word,neighbors]+1

print('done!')
# Out:
# done!

# %%
adjacency
# Out:
#                             East last autumn  readiness such as  \
# East last autumn                           0                  0
# readiness such as                          0                  0
# impressionability which is                 0                  0
# my tolerance come                          0                  0
# being politician because                   0                  0
# ...                                      ...                ...
# those intricate machines                   0                  0
# he were related                            0                  0
# when realized by                           0                  0
# for hope romantic                          0                  1
# not few veteran                            0                  0
#
#                             impressionability which is  my tolerance come  \
# East last autumn                                     0                  0
# readiness such as                                    0                  0
# impressionability which is                           0                  0
# my tolerance come                                    0                  0
# being politician because                             0                  0
# ...                                                ...                ...
# those intricate machines                             0                  0
# he were related                                      0                  0
# when realized by                                     0                  0
# for hope romantic                                    0                  0
# not few veteran                                      0                  0
#
#                             being politician because  from my reaction  \
# East last autumn                                   0                 0
# readiness such as                                  0                 0
# impressionability which is                         0                 0
# my tolerance come                                  0                 0
# being politician because                           0                 0
# ...                                              ...               ...
# those intricate machines                           0                 0
# he were related                                    0                 0
# when realized by                                   0                 0
# for hope romantic                                  0                 0
# not few veteran                                    0                 0
#
#                             an intimate revelation  revelation was quivering  \
# East last autumn                                 0                         0
# readiness such as                                0                         0
# impressionability which is                       0                         0
# my tolerance come                                0                         0
# being politician because                         0                         0
# ...                                            ...                       ...
# those intricate machines                         0                         0
# he were related                                  0                         0
# when realized by                                 0                         0
# for hope romantic                                0                         0
# not few veteran                                  0                         0
#
#                             he told me  sorrows and short  ...  \
# East last autumn                     0                  0  ...
# readiness such as                    0                  0  ...
# impressionability which is           0                  0  ...
# my tolerance come                    0                  0  ...
# being politician because             0                  0  ...
# ...                                ...                ...  ...
# those intricate machines             0                  0  ...
# he were related                      0                  0  ...
# when realized by                     0                  0  ...
# for hope romantic                    0                  0  ...
# not few veteran                      0                  0  ...
#
#                             personality is an  ve been turning  \
# East last autumn                            0                0
# readiness such as                           0                0
# impressionability which is                  0                0
# my tolerance come                           0                0
# being politician because                    0                0
# ...                                       ...              ...
# those intricate machines                    0                0
# he were related                             0                0
# when realized by                            0                0
# for hope romantic                           0                0
# not few veteran                             0                0
#
#                             temporarily closed out  that as my  as my father  \
# East last autumn                                 0           0             0
# readiness such as                                0           0             0
# impressionability which is                       0           0             0
# my tolerance come                                0           0             0
# being politician because                         0           0             0
# ...                                            ...         ...           ...
# those intricate machines                         0           0             0
# he were related                                  0           0             0
# when realized by                                 0           0             0
# for hope romantic                                0           0             0
# not few veteran                                  0           0             0
#
#                             those intricate machines  he were related  \
# East last autumn                                   0                0
# readiness such as                                  0                0
# impressionability which is                         0                0
# my tolerance come                                  0                0
# being politician because                           0                0
# ...                                              ...              ...
# those intricate machines                           0                0
# he were related                                    0                0
# when realized by                                   0                0
# for hope romantic                                  0                0
# not few veteran                                    0                0
#
#                             when realized by  for hope romantic  \
# East last autumn                           0                  0
# readiness such as                          0                  0
# impressionability which is                 0                  0
# my tolerance come                          0                  0
# being politician because                   0                  0
# ...                                      ...                ...
# those intricate machines                   0                  0
# he were related                            0                  0
# when realized by                           0                  0
# for hope romantic                          0                  0
# not few veteran                            0                  0
#
#                             not few veteran
# East last autumn                          0
# readiness such as                         0
# impressionability which is                0
# my tolerance come                         0
# being politician because                  0
# ...                                     ...
# those intricate machines                  0
# he were related                           0
# when realized by                          0
# for hope romantic                         0
# not few veteran                           0
#
# [428 rows x 428 columns]

# %%
gatsby_trigrams
# Out:
# ['In my younger',
#  'my younger and',
#  'younger and more',
#  'and more vulnerable',
#  'more vulnerable years',
#  'vulnerable years my',
#  'years my father',
#  'my father gave',
#  'father gave me',
#  'gave me some',
#  'me some advice',
#  'some advice that',
#  'advice that ve',
#  'that ve been',
#  've been turning',
#  'been turning over',
#  'turning over in',
#  'over in my',
#  'in my mind',
#  'my mind ever',
#  'mind ever since',
#  'Whenever you feel',
#  'you feel like',
#  'feel like criticizing',
#  'like criticizing any',
#  'criticizing any one',
#  'any one he',
#  'one he told',
#  'he told me',
#  'told me just',
#  'me just remember',
#  'just remember that',
#  'remember that all',
#  'that all the',
#  'all the people',
#  'the people in',
#  'people in this',
#  'in this world',
#  'this world haven',
#  'world haven had',
#  'haven had the',
#  'had the advantages',
#  'the advantages that',
#  'advantages that you',
#  'that you ve',
#  'you ve had',
#  'He didn say',
#  'didn say any',
#  'say any more',
#  'but we ve',
#  'we ve always',
#  've always been',
#  'always been unusually',
#  'been unusually communicative',
#  'unusually communicative in',
#  'communicative in reserved',
#  'in reserved way',
#  'reserved way and',
#  'understood that he',
#  'that he meant',
#  'he meant great',
#  'meant great deal',
#  'great deal more',
#  'deal more than',
#  'more than that',
#  'In consequence inclined',
#  'consequence inclined to',
#  'inclined to reserve',
#  'to reserve all',
#  'reserve all judgments',
#  'all judgments habit',
#  'judgments habit that',
#  'habit that has',
#  'that has opened',
#  'has opened up',
#  'opened up many',
#  'up many curious',
#  'many curious natures',
#  'curious natures to',
#  'natures to me',
#  'to me and',
#  'me and also',
#  'and also made',
#  'also made me',
#  'made me the',
#  'me the victim',
#  'the victim of',
#  'victim of not',
#  'of not few',
#  'not few veteran',
#  'few veteran bores',
#  'The abnormal mind',
#  'abnormal mind is',
#  'mind is quick',
#  'is quick to',
#  'quick to detect',
#  'to detect and',
#  'detect and attach',
#  'and attach itself',
#  'attach itself to',
#  'itself to this',
#  'to this quality',
#  'this quality when',
#  'quality when it',
#  'when it appears',
#  'it appears in',
#  'appears in normal',
#  'in normal person',
#  'normal person and',
#  'person and so',
#  'and so it',
#  'so it came',
#  'it came about',
#  'came about that',
#  'about that in',
#  'that in college',
#  'in college was',
#  'college was unjustly',
#  'was unjustly accused',
#  'unjustly accused of',
#  'accused of being',
#  'of being politician',
#  'being politician because',
#  'politician because was',
#  'because was privy',
#  'was privy to',
#  'privy to the',
#  'to the secret',
#  'the secret griefs',
#  'secret griefs of',
#  'griefs of wild',
#  'of wild unknown',
#  'wild unknown men',
#  'Most of the',
#  'of the confidences',
#  'the confidences were',
#  'confidences were unsought',
#  'frequently have feigned',
#  'have feigned sleep',
#  'feigned sleep preoccupation',
#  'sleep preoccupation or',
#  'preoccupation or hostile',
#  'or hostile levity',
#  'hostile levity when',
#  'levity when realized',
#  'when realized by',
#  'realized by some',
#  'by some unmistakable',
#  'some unmistakable sign',
#  'unmistakable sign that',
#  'sign that an',
#  'that an intimate',
#  'an intimate revelation',
#  'intimate revelation was',
#  'revelation was quivering',
#  'was quivering on',
#  'quivering on the',
#  'on the horizon',
#  'the horizon for',
#  'horizon for the',
#  'for the intimate',
#  'the intimate revelations',
#  'intimate revelations of',
#  'revelations of young',
#  'of young men',
#  'young men or',
#  'men or at',
#  'or at least',
#  'at least the',
#  'least the terms',
#  'the terms in',
#  'terms in which',
#  'in which they',
#  'which they express',
#  'they express them',
#  'express them are',
#  'them are usually',
#  'are usually plagiaristic',
#  'usually plagiaristic and',
#  'plagiaristic and marred',
#  'and marred by',
#  'marred by obvious',
#  'by obvious suppressions',
#  'Reserving judgments is',
#  'judgments is matter',
#  'is matter of',
#  'matter of infinite',
#  'of infinite hope',
#  'am still little',
#  'still little afraid',
#  'little afraid of',
#  'afraid of missing',
#  'of missing something',
#  'missing something if',
#  'something if forget',
#  'if forget that',
#  'forget that as',
#  'that as my',
#  'as my father',
#  'my father snobbishly',
#  'father snobbishly suggested',
#  'snobbishly suggested and',
#  'suggested and snobbishly',
#  'and snobbishly repeat',
#  'snobbishly repeat sense',
#  'repeat sense of',
#  'sense of the',
#  'of the fundamental',
#  'the fundamental decencies',
#  'fundamental decencies is',
#  'decencies is parcelled',
#  'is parcelled out',
#  'parcelled out unequally',
#  'out unequally at',
#  'unequally at birth',
#  'And after boasting',
#  'after boasting this',
#  'boasting this way',
#  'this way of',
#  'way of my',
#  'of my tolerance',
#  'my tolerance come',
#  'tolerance come to',
#  'come to the',
#  'to the admission',
#  'the admission that',
#  'admission that it',
#  'that it has',
#  'it has limit',
#  'Conduct may be',
#  'may be founded',
#  'be founded on',
#  'founded on the',
#  'on the hard',
#  'the hard rock',
#  'hard rock or',
#  'rock or the',
#  'or the wet',
#  'the wet marshes',
#  'wet marshes but',
#  'marshes but after',
#  'but after certain',
#  'after certain point',
#  'certain point don',
#  'point don care',
#  'don care what',
#  'care what it',
#  'what it founded',
#  'it founded on',
#  'When came back',
#  'came back from',
#  'back from the',
#  'from the East',
#  'the East last',
#  'East last autumn',
#  'felt that wanted',
#  'that wanted the',
#  'wanted the world',
#  'the world to',
#  'world to be',
#  'to be in',
#  'be in uniform',
#  'in uniform and',
#  'uniform and at',
#  'and at sort',
#  'at sort of',
#  'sort of moral',
#  'of moral attention',
#  'moral attention forever',
#  'attention forever wanted',
#  'forever wanted no',
#  'wanted no more',
#  'no more riotous',
#  'more riotous excursions',
#  'riotous excursions with',
#  'excursions with privileged',
#  'with privileged glimpses',
#  'privileged glimpses into',
#  'glimpses into the',
#  'into the human',
#  'the human heart',
#  'Only Gatsby the',
#  'Gatsby the man',
#  'the man who',
#  'man who gives',
#  'who gives his',
#  'gives his name',
#  'his name to',
#  'name to this',
#  'to this book',
#  'this book was',
#  'book was exempt',
#  'was exempt from',
#  'exempt from my',
#  'from my reaction',
#  'my reaction Gatsby',
#  'reaction Gatsby who',
#  'Gatsby who represented',
#  'who represented everything',
#  'represented everything for',
#  'everything for which',
#  'for which have',
#  'which have an',
#  'have an unaffected',
#  'an unaffected scorn',
#  'If personality is',
#  'personality is an',
#  'is an unbroken',
#  'an unbroken series',
#  'unbroken series of',
#  'series of successful',
#  'of successful gestures',
#  'successful gestures then',
#  'gestures then there',
#  'then there was',
#  'there was something',
#  'was something gorgeous',
#  'something gorgeous about',
#  'gorgeous about him',
#  'about him some',
#  'him some heightened',
#  'some heightened sensitivity',
#  'heightened sensitivity to',
#  'sensitivity to the',
#  'to the promises',
#  'the promises of',
#  'promises of life',
#  'of life as',
#  'life as if',
#  'as if he',
#  'if he were',
#  'he were related',
#  'were related to',
#  'related to one',
#  'to one of',
#  'one of those',
#  'of those intricate',
#  'those intricate machines',
#  'intricate machines that',
#  'machines that register',
#  'that register earthquakes',
#  'register earthquakes ten',
#  'earthquakes ten thousand',
#  'ten thousand miles',
#  'thousand miles away',
#  'This responsiveness had',
#  'responsiveness had nothing',
#  'had nothing to',
#  'nothing to do',
#  'to do with',
#  'do with that',
#  'with that flabby',
#  'that flabby impressionability',
#  'flabby impressionability which',
#  'impressionability which is',
#  'which is dignified',
#  'is dignified under',
#  'dignified under the',
#  'under the name',
#  'the name of',
#  'name of the',
#  'of the creative',
#  'the creative temperament',
#  'creative temperament it',
#  'temperament it was',
#  'it was an',
#  'was an extraordinary',
#  'an extraordinary gift',
#  'extraordinary gift for',
#  'gift for hope',
#  'for hope romantic',
#  'hope romantic readiness',
#  'romantic readiness such',
#  'readiness such as',
#  'such as have',
#  'as have never',
#  'have never found',
#  'never found in',
#  'found in any',
#  'in any other',
#  'any other person',
#  'other person and',
#  'person and which',
#  'it is not',
#  'is not likely',
#  'not likely shall',
#  'likely shall ever',
#  'shall ever find',
#  'ever find again',
#  'No Gatsby turned',
#  'Gatsby turned out',
#  'turned out all',
#  'out all right',
#  'all right at',
#  'right at the',
#  'at the end',
#  'the end it',
#  'end it is',
#  'it is what',
#  'is what preyed',
#  'what preyed on',
#  'preyed on Gatsby',
#  'on Gatsby what',
#  'Gatsby what foul',
#  'what foul dust',
#  'foul dust floated',
#  'dust floated in',
#  'floated in the',
#  'in the wake',
#  'the wake of',
#  'wake of his',
#  'of his dreams',
#  'his dreams that',
#  'dreams that temporarily',
#  'that temporarily closed',
#  'temporarily closed out',
#  'closed out my',
#  'out my interest',
#  'my interest in',
#  'interest in the',
#  'in the abortive',
#  'the abortive sorrows',
#  'abortive sorrows and',
#  'sorrows and short',
#  'and short winded',
#  'short winded elations',
#  'winded elations of',
#  'elations of men']

# %%
# Running TextRank
#nx_words = nx.from_numpy_matrix(adjacency.as_matrix()) #<--gave me a FutureWarning and suggested .values. So...
nx_words = nx.from_numpy_matrix(adjacency.values)
ranks=nx.pagerank(nx_words, alpha=.85, tol=.00000001)

# Identifying the five most highly ranked keywords
ranked = sorted(((ranks[i],s) for i,s in enumerate(words)),
                reverse=True)
print(ranked[:5])
# Out:
# [(0.0026351630280416856, 'sorrows and short'), (0.002635163028041685, 'more vulnerable years'), (0.0025770839316087034, 'abortive sorrows and'), (0.002577083931608703, 'vulnerable years my'), (0.0025311269517034147, 'the abortive sorrows')]

# %% [markdown]
# I see that there was a drop in the scores of the highest-ranked keywords/Ngrams as N increased from 1 to 1+. Not much of a difference between the scores of N-grams where N=2 or N=3.
