# %% [markdown]
# Adapted from https://github.com/amanthedorkknight/fifa18-all-player-statistics/blob/master/2019/crawler.py

# %%
#!/usr/bin/env python3

# Adapted from https://github.com/amanthedorkknight/fifa18-all-player-statistics/blob/master/2019/crawler.py

import sys
from time import sleep
from random import randint
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

import logging,sys
logging.basicConfig(stream=sys.stderr, level=logging.INFO)

# Build a full list of players. Set this to False for a rerun where we've already gathered this information.
get_basic_player_info = True
saved_player_list = 'basic_player_info.json.zip'

# If you want to write blocks of player records to the CSV more or less often,
# change player_block_size. Don't mess with processed_count.
player_block_size = 500
processed_count = 1

output_file = 'data.csv'

# Overwrite an existing output CSV (this switches to 'a' in the loop, to append)
to_csv_mode = 'w'

# Only write a header the first time we write to the CSV.
write_header = True

base_url = "https://sofifa.com/players?offset="
columns = ['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special']
data = pd.DataFrame(columns = columns)

# %%
# Get basic players information for all players
if (get_basic_player_info):
    for offset in range(0, 300):
        url = base_url + str(offset * 61)
        source_code = requests.get(url)
        plain_text = source_code.text
        soup = BeautifulSoup(plain_text, 'html.parser')
        table_body = soup.find('tbody')
        for row in table_body.findAll('tr'):
            td = row.findAll('td')
            picture = td[0].find('img').get('data-src')
            pid = td[0].find('img').get('id')
            nationality = td[1].find('a').get('title')
            flag_img = td[1].find('img').get('data-src')
            name = td[1].findAll('a')[1].text
            logging.info("Retrieving player info for {}, ID {}".format(name,pid))
            age = td[2].text.strip()
            overall = td[3].text.strip()
            potential = td[4].text.strip()
            club = td[5].find('a').text
            club_logo = td[5].find('img').get('data-src')
            value = td[6].text.strip()
            wage = td[7].text.strip()
            special = td[8].text.strip()
            player_data = pd.DataFrame([[pid, name, age, picture, nationality, flag_img, overall, potential, club, club_logo, value, wage, special]])
            player_data.columns = columns
            data = data.append(player_data, ignore_index=True)
    data = data.drop_duplicates()

# Write basic player info, so we don't have to retrieve it again in a rerun.
    data.to_json(saved_player_list,orient='split',index=False)
else:
# Try reading the players list from a saved file
    data = pd.read_json(saved_player_list,orient='split')
    logging.info("Successfully read {}".format(saved_player_list))
# Out:
# INFO:root:Retrieving player info for Borja Iglesias, ID 224179
# INFO:root:Retrieving player info for D. Man, ID 239978
# INFO:root:Retrieving player info for D. Arzani, ID 234867
# INFO:root:Retrieving player info for L. Waldschmidt, ID 220085
# INFO:root:Retrieving player info for A. Halilović, ID 216349
# INFO:root:Retrieving player info for C. Nkunku, ID 232411
# INFO:root:Retrieving player info for P. Foden, ID 237692
# INFO:root:Retrieving player info for Savio, ID 8287
# INFO:root:Retrieving player info for K. Havertz, ID 235790
# INFO:root:Retrieving player info for Adama Traoré, ID 213956
# INFO:root:Retrieving player info for S. Gnabry, ID 206113
# INFO:root:Retrieving player info for João Félix, ID 242444
# INFO:root:Retrieving player info for E. Håland, ID 239085
# INFO:root:Retrieving player info for M. Kean, ID 236610
# INFO:root:Retrieving player info for Fábio Silva, ID 252037
# INFO:root:Retrieving player info for D. Malen, ID 231447
# INFO:root:Retrieving player info for N. Domínguez, ID 237819
# INFO:root:Retrieving player info for T. Almada, ID 245371
# INFO:root:Retrieving player info for M. Ihattaren, ID 246960
# INFO:root:Retrieving player info for S. Tonali, ID 241096
# INFO:root:Retrieving player info for Rodrygo, ID 243812
# INFO:root:Retrieving player info for L. Martínez, ID 231478
# INFO:root:Retrieving player info for F. Coman, ID 238274
# INFO:root:Retrieving player info for M. Greenwood, ID 246147
# INFO:root:Retrieving player info for P. De la Vega, ID 246045
# INFO:root:Retrieving player info for J. David, ID 243630
# INFO:root:Retrieving player info for C. Hudson-Odoi, ID 240740
# INFO:root:Retrieving player info for E. Palacios, ID 231521
# INFO:root:Retrieving player info for J. Sancho, ID 233049
# INFO:root:Retrieving player info for A. Urzi, ID 246469
# INFO:root:Retrieving player info for L. Alario, ID 215353
# INFO:root:Retrieving player info for A. Davies, ID 234396
# INFO:root:Retrieving player info for T. Abraham, ID 231352
# INFO:root:Retrieving player info for D. Szoboszlai, ID 236772
# INFO:root:Retrieving player info for M. Mount, ID 233064
# INFO:root:Retrieving player info for F. de Jong, ID 228702
# INFO:root:Retrieving player info for I. Konaté, ID 237678
# INFO:root:Retrieving player info for T. Kubo, ID 237681
# INFO:root:Retrieving player info for D. Upamecano, ID 229558
# INFO:root:Retrieving player info for J. Vagnoman, ID 242602
# INFO:root:Retrieving player info for M. Ødegaard, ID 222665
# INFO:root:Retrieving player info for Dani Olmo, ID 244260
# INFO:root:Retrieving player info for Vinícius Jr., ID 238794
# INFO:root:Retrieving player info for Fabián, ID 226271
# INFO:root:Retrieving player info for A. Saint-Maximin, ID 216388
# INFO:root:Retrieving player info for J. Maddison, ID 220697
# INFO:root:Retrieving player info for L. Klostermann, ID 222331
# INFO:root:Retrieving player info for D. Rice, ID 234378
# INFO:root:Retrieving player info for A. Sigurðsson, ID 238196
# INFO:root:Retrieving player info for A. Hložek, ID 246618
# INFO:root:Retrieving player info for J. Todibo, ID 245388
# INFO:root:Retrieving player info for K. Mbappé, ID 231747
# INFO:root:Retrieving player info for D. van de Beek, ID 221363
# INFO:root:Retrieving player info for W. Saliba, ID 243715
# INFO:root:Retrieving player info for Kangin Lee, ID 243780
# INFO:root:Retrieving player info for K. Hoever, ID 246763
# INFO:root:Retrieving player info for B. Saka, ID 246669
# INFO:root:Retrieving player info for Y. Verschaeren, ID 246419
# INFO:root:Retrieving player info for Bernardo Silva, ID 218667
# INFO:root:Retrieving player info for R. Koch, ID 236532
# INFO:root:Retrieving player info for E. Ampadu, ID 235735
# INFO:root:Retrieving player info for L. Jović, ID 232432
# INFO:root:Retrieving player info for A. Nübel, ID 223885
# INFO:root:Retrieving player info for Florentino, ID 234569
# INFO:root:Retrieving player info for Nuno Tavares, ID 251530
# INFO:root:Retrieving player info for J. Kimmich, ID 212622
# INFO:root:Retrieving player info for R. James, ID 238074
# INFO:root:Retrieving player info for S. Berge, ID 228092
# INFO:root:Retrieving player info for M. de Ligt, ID 235243
# INFO:root:Retrieving player info for T. Alexander-Arnold, ID 231281
# INFO:root:Retrieving player info for L. Bailey, ID 229906
# INFO:root:Retrieving player info for F. Tomori, ID 232756
# INFO:root:Retrieving player info for M. Guendouzi, ID 236496
# INFO:root:Retrieving player info for S. Bergwijn, ID 225953
# INFO:root:Retrieving player info for A. Gomes, ID 240507
# INFO:root:Retrieving player info for A. Maier, ID 237629
# INFO:root:Retrieving player info for A. Robertson, ID 216267
# INFO:root:Retrieving player info for David Neres, ID 236632
# INFO:root:Retrieving player info for W. McKennie, ID 238744
# INFO:root:Retrieving player info for N. Mukiele, ID 226166
# INFO:root:Retrieving player info for Brahim, ID 231410
# INFO:root:Retrieving player info for Diogo Dalot, ID 234574
# INFO:root:Retrieving player info for Grimaldo, ID 210035
# INFO:root:Retrieving player info for M. Depay, ID 202556
# INFO:root:Retrieving player info for C. Romero, ID 232488
# INFO:root:Retrieving player info for T. Müller, ID 189596
# INFO:root:Retrieving player info for L. Goretzka, ID 209658
# INFO:root:Retrieving player info for T. Kehrer, ID 226229
# INFO:root:Retrieving player info for A. Marin, ID 244267
# INFO:root:Retrieving player info for O. Zinchenko, ID 227813
# INFO:root:Retrieving player info for Rúben Dias, ID 239818
# INFO:root:Retrieving player info for M. Zaracho, ID 235926
# INFO:root:Retrieving player info for M. Škriniar, ID 232363
# INFO:root:Retrieving player info for S. Esposito, ID 247888
# INFO:root:Retrieving player info for C. Eriksen, ID 190460
# INFO:root:Retrieving player info for Renan Lodi, ID 251573
# INFO:root:Retrieving player info for M. Gibbs-White, ID 236015
# INFO:root:Retrieving player info for P. Cutrone, ID 237715
# INFO:root:Retrieving player info for Junior Firpo, ID 241184
# INFO:root:Retrieving player info for W. Zaha, ID 198717
# INFO:root:Retrieving player info for Emerson, ID 247204
# INFO:root:Retrieving player info for Cristiano Ronaldo, ID 20801
# INFO:root:Retrieving player info for Neymar Jr, ID 190871
# INFO:root:Retrieving player info for C. Pavón, ID 224254
# INFO:root:Retrieving player info for R. Bentancur, ID 227535
# INFO:root:Retrieving player info for Gabriel Jesus, ID 230666
# INFO:root:Retrieving player info for H. Ziyech, ID 208670
# INFO:root:Retrieving player info for L. Martínez, ID 239301
# INFO:root:Retrieving player info for S. Longstaff, ID 237161
# INFO:root:Retrieving player info for Y. Tielemans, ID 216393
# INFO:root:Retrieving player info for C. Pulisic, ID 227796
# INFO:root:Retrieving player info for K. Piątek, ID 223113
# INFO:root:Retrieving player info for Medrán, ID 212476
# INFO:root:Retrieving player info for M. Akanji, ID 229237
# INFO:root:Retrieving player info for Gonçalo Guedes, ID 224411
# INFO:root:Retrieving player info for M. Eggestein, ID 226168
# INFO:root:Retrieving player info for S. Mané, ID 208722
# INFO:root:Retrieving player info for T. Adams, ID 232999
# INFO:root:Retrieving player info for Nélson Semedo, ID 227928
# INFO:root:Retrieving player info for V. van Dijk, ID 203376
# INFO:root:Retrieving player info for Hwang Hee Chan, ID 226380
# INFO:root:Retrieving player info for E. Ndicka, ID 236403
# INFO:root:Retrieving player info for N. Barella, ID 224232
# INFO:root:Retrieving player info for J. Brandt, ID 212194

# %%
logging.info("Player info dataframe shape: {}".format(data.shape))
# Out:
# INFO:root:Player info dataframe shape: (180, 13)

# %%
# Get detailed player information from player page.
# 2020 updates: 'Release Clause' and 'DefensiveAwareness' added.
detailed_columns = ['ID', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Player Positions', 'Position', 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until', 'Release Clause', 'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'DefensiveAwareness', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']
detailed_data = pd.DataFrame(index = range(0, data.count()[0]), columns = detailed_columns)
player_data_url = 'https://sofifa.com/player/'

# %%
for id in data.ID:
# It's rude to hammer a website with requests. Let's sleep for some random amount of time to slow things down.
    sleep(randint(1,5))

    skill_map = {}
    logging.info("Retrieving individual info for player ID {}. Processed {}/{}".format(id,processed_count,player_block_size))
    url = player_data_url + str(id)
    try:
        source_code = requests.get(url)
    except:
        logging.info("Unable to retrieve info for player ID {}! Skipping.".format(id))
        continue
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text, 'html.parser')

# Metadata format is: first_name, last_name, flag (returns an empty string), position(s), 'Age', age_number, '('+birth_month, birth_day+',', birth_year+')'
    meta_data = soup.find('div', {'class': 'meta'}).text.split(' ')
    length = len(meta_data)
    flag_space_ind = meta_data.index('')
    age_string_ind = meta_data.index('Age')
# We'll capture all of the positions listed here now. We can decide what to do with them in analysis.
    skill_map['Player Positions'] = str.join(' ',meta_data[flag_space_ind+1:age_string_ind])
    weight = meta_data[length - 1]
    height = meta_data[length - 2].split('\'')[0] + '\'' + meta_data[length - 2].split('\'')[1].split('\"')[0]
    skill_map["Height"] = height
    skill_map['Weight'] = weight

# Players' attributes have been split across a few different classes, so we'll extract values from all of them.
    for col_idx in [5,6]:
        columns = soup.find('div', {'class': 'teams'}).find('div', {'class': 'columns'}).find_all('div', {'class': 'column col-{}'.format(col_idx)})
        for column in columns:
            skills = column.find_all('li')
            for skill in skills:
                if(skill.find('label') != None):
                    label = skill.find('label').text
                    value = skill.text.replace(label, '').strip()
                    skill_map[label] = value

# col-5 information (the team to which a player belongs, and the position they play) may not be populated.
# If it isn't, use the first position listed next to their name as Position.
    if('Position' not in skill_map.keys()):
        skill_map['Position'] = meta_data[3]


# Position scores have been moved outside of the 'article' tag to an 'aside' tag.
# Goalkeepers don't have these stats.
    if (skill_map['Position'] != 'GK'):
        positions = soup.find('aside').find_all('div', class_='columns')
        for position in positions:
            for pos_div in position.find_all('div', class_=re.compile('column col-sm-2 text-center p')):
                my_output = re.split(r'(\d+)',pos_div.text,maxsplit=1)
                my_output[0] = my_output[0][1:]

# There is a bonus awarded to some players. Capture it--we can decide what to do with it in analysis.
                skill_map[my_output[0]] = str.join('',my_output[1:3])

# The rest of the players' attributes have been split into a bunch of classes as well.
# Bonus work, tbd: Capture the class information regarding the players' skill levels in each area--
#  tags look like "bp3-intent-(success|warning|danger)". Could be useful summary info?
    sections = soup.find('article').find_all('div', class_=re.compile('bp3-callout '))[2:]
    for section in sections:
        items = section.find('ul').find_all('li')
        for item in items:
            value = int(re.findall(r'\d+', item.text)[0])
            name = ''.join(re.findall('[a-zA-Z]*', item.text))
            skill_map[str(name)] = value

    detailed_data = detailed_data.append({'ID': id},ignore_index=True)
    for key, value in skill_map.items():
        detailed_data.loc[detailed_data.ID == id, key] = value
    processed_count += 1

# Have we processed a full block of records? If so, merge and write them to the CSV.
    if (processed_count > player_block_size):
        logging.info("Merging player data...")
        full_data = pd.merge(data, detailed_data, how = 'inner', on = 'ID')
        logging.info("Writing player data to CSV...")
        full_data.to_csv(output_file, encoding='utf-8-sig',mode=to_csv_mode,header=write_header)
        processed_count = 1
        to_csv_mode = 'a'
        write_header = False
        detailed_data = pd.DataFrame(index = range(0, data.count()[0]), columns = detailed_columns)
# INFO:root:Retrieving individual info for player ID 237715. Processed 155/500
# INFO:root:Retrieving individual info for player ID 241184. Processed 156/500
# INFO:root:Retrieving individual info for player ID 198717. Processed 157/500
# INFO:root:Retrieving individual info for player ID 247204. Processed 158/500
# INFO:root:Retrieving individual info for player ID 20801. Processed 159/500
# INFO:root:Retrieving individual info for player ID 190871. Processed 160/500
# INFO:root:Retrieving individual info for player ID 224254. Processed 161/500
# INFO:root:Retrieving individual info for player ID 227535. Processed 162/500
# INFO:root:Retrieving individual info for player ID 230666. Processed 163/500
# INFO:root:Retrieving individual info for player ID 208670. Processed 164/500
# INFO:root:Retrieving individual info for player ID 239301. Processed 165/500
# INFO:root:Retrieving individual info for player ID 237161. Processed 166/500
# INFO:root:Retrieving individual info for player ID 216393. Processed 167/500
# INFO:root:Retrieving individual info for player ID 227796. Processed 168/500
# INFO:root:Retrieving individual info for player ID 223113. Processed 169/500
# INFO:root:Retrieving individual info for player ID 212476. Processed 170/500
# INFO:root:Retrieving individual info for player ID 229237. Processed 171/500
# INFO:root:Retrieving individual info for player ID 224411. Processed 172/500
# INFO:root:Retrieving individual info for player ID 226168. Processed 173/500
# INFO:root:Retrieving individual info for player ID 208722. Processed 174/500
# INFO:root:Retrieving individual info for player ID 232999. Processed 175/500
# INFO:root:Retrieving individual info for player ID 227928. Processed 176/500
# INFO:root:Retrieving individual info for player ID 203376. Processed 177/500
# INFO:root:Retrieving individual info for player ID 226380. Processed 178/500
# INFO:root:Retrieving individual info for player ID 236403. Processed 179/500
# INFO:root:Retrieving individual info for player ID 224232. Processed 180/500
# INFO:root:Retrieving individual info for player ID 212194. Processed 181/500

# %%
# One final merge and write to cover whatever we haven't yet processed
logging.info("Merging player data...")
full_data = pd.merge(data, detailed_data, how = 'inner', on = 'ID')
logging.info("Writing player data to CSV...")
full_data.to_csv(output_file, encoding='utf-8-sig',mode=to_csv_mode,header=write_header)
# Out:
# INFO:root:Merging player data...
# INFO:root:Writing player data to CSV...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17948 entries, 0 to 17947
# Data columns (total 13 columns):
# ID             17948 non-null int64
# Name           17948 non-null object
# Age            17948 non-null int64
# Photo          17948 non-null object
# Nationality    17948 non-null object
# Flag           17948 non-null object
# Overall        17948 non-null int64
# Potential      17948 non-null int64
# Club           17948 non-null object
# Club Logo      17948 non-null object
# Value          17948 non-null object
# Wage           17948 non-null object
# Special        17948 non-null int64
# dtypes: int64(5), object(8)
# memory usage: 1.8+ MB

# %%
meta_data
# Out:
# ['Julian',
#  'Brandt',
#  '',
#  'CAM',
#  'LM',
#  'RM',
#  'Age',
#  '23',
#  '(May',
#  '2,',
#  '1996)',
#  '6\'1"',
#  '183lbs']

# %%
length = len(meta_data)
flag_space_ind = meta_data.index('')
age_string_ind = meta_data.index('Age')

# %%
flag_space_ind
# Out:
# 2

# %%
age_string_ind
# Out:
# 5

# %%
meta_data[flag_space_ind+1:age_string_ind]
# Out:
# ['CF', 'ST']

# %%
skill_map['Player Positions'] = meta_data[flag_space_ind+1:age_string_ind]

# %%
pos_div.text
# Out:
# '\nRB50+2'

# %%
my_output = re.split(r'(\d+)',pos_div.text,maxsplit=1)
my_output
# Out:
# ['\nRB', '50', '+2']

# %%
skill_map
# Out:
# {'Player Positions': ['RM', 'RW'],
#  'Height': "6'0",
#  'Weight': '181lbs',
#  'Position': 'RW',
#  'Jersey Number': '98',
#  'Joined': 'Sep 5, 2016',
#  'Contract Valid Until': '2022',
#  'Preferred Foot': 'Left',
#  'International Reputation': '1',
#  'Weak Foot': '2',
#  'Skill Moves': '3',
#  'Work Rate': 'High/ Low',
#  'Body Type': 'Normal',
#  'Real Face': 'No',
#  'Release Clause': '€8.8M',
#  'LS': '71+2',
#  'ST': '71+2',
#  'RS': '71+2',
#  'LW': '71+2',
#  'LF': '71+2',
#  'CF': '71+2',
#  'RF': '71+2',
#  'RW': '71+2',
#  'LAM': '69+2',
#  'CAM': '69+2',
#  'RAM': '69+2',
#  'LM': '70+2',
#  'LCM': '62+2',
#  'CM': '62+2',
#  'RCM': '62+2',
#  'RM': '70+2',
#  'LWB': '54+2',
#  'LDM': '50+2',
#  'CDM': '50+2',
#  'RDM': '50+2',
#  'RWB': '54+2',
#  'LB': '51+2',
#  'LCB': '47+2',
#  'CB': '47+2',
#  'RCB': '47+2',
#  'RB': '51+2',
#  'Crossing': 66,
#  'Finishing': 73,
#  'HeadingAccuracy': 63,
#  'ShortPassing': 66,
#  'Volleys': 57,
#  'Dribbling': 71,
#  'Curve': 64,
#  'FKAccuracy': 56,
#  'LongPassing': 54,
#  'BallControl': 73,
#  'Acceleration': 86,
#  'SprintSpeed': 86,
#  'Agility': 73,
#  'Reactions': 65,
#  'Balance': 57,
#  'ShotPower': 71,
#  'Jumping': 80,
#  'Stamina': 68,
#  'Strength': 75,
#  'LongShots': 60,
#  'Aggression': 68,
#  'Interceptions': 17,
#  'Positioning': 76,
#  'Vision': 67,
#  'Penalties': 43,
#  'Composure': 72,
#  'DefensiveAwareness': 23,
#  'StandingTackle': 38,
#  'SlidingTackle': 32,
#  'GKDiving': 5,
#  'GKHandling': 13,
#  'GKKicking': 7,
#  'GKPositioning': 8,
#  'GKReflexes': 13}

# %%
detailed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17949 entries, 0 to 17948
# Data columns (total 77 columns):
# ID                          1 non-null float64
# Preferred Foot              1 non-null object
# International Reputation    1 non-null object
# Weak Foot                   1 non-null object
# Skill Moves                 1 non-null object
# Work Rate                   1 non-null object
# Body Type                   1 non-null object
# Real Face                   1 non-null object
# Position                    1 non-null object
# Jersey Number               1 non-null object
# Joined                      1 non-null object
# Loaned From                 0 non-null float64
# Contract Valid Until        1 non-null object
# Release Clause              1 non-null object
# Height                      1 non-null object
# Weight                      1 non-null object
# LS                          1 non-null float64
# ST                          1 non-null float64
# RS                          1 non-null float64
# LW                          1 non-null float64
# LF                          1 non-null float64
# CF                          1 non-null float64
# RF                          1 non-null float64
# RW                          1 non-null float64
# LAM                         1 non-null float64
# CAM                         1 non-null float64
# RAM                         1 non-null float64
# LM                          1 non-null float64
# LCM                         1 non-null float64
# CM                          1 non-null float64
# RCM                         1 non-null float64
# RM                          1 non-null float64
# LWB                         1 non-null float64
# LDM                         1 non-null float64
# CDM                         1 non-null float64
# RDM                         1 non-null float64
# RWB                         1 non-null float64
# LB                          1 non-null float64
# LCB                         1 non-null float64
# CB                          1 non-null float64
# RCB                         1 non-null float64
# RB                          1 non-null float64
# Crossing                    1 non-null float64
# Finishing                   1 non-null float64
# HeadingAccuracy             1 non-null float64
# ShortPassing                1 non-null float64
# Volleys                     1 non-null float64
# Dribbling                   1 non-null float64
# Curve                       1 non-null float64
# FKAccuracy                  1 non-null float64
# LongPassing                 1 non-null float64
# BallControl                 1 non-null float64
# Acceleration                1 non-null float64
# SprintSpeed                 1 non-null float64
# Agility                     1 non-null float64
# Reactions                   1 non-null float64
# Balance                     1 non-null float64
# ShotPower                   1 non-null float64
# Jumping                     1 non-null float64
# Stamina                     1 non-null float64
# Strength                    1 non-null float64
# LongShots                   1 non-null float64
# Aggression                  1 non-null float64
# Interceptions               1 non-null float64
# Positioning                 1 non-null float64
# Vision                      1 non-null float64
# Penalties                   1 non-null float64
# Composure                   1 non-null float64
# Marking                     0 non-null float64
# DefensiveAwareness          1 non-null float64
# StandingTackle              1 non-null float64
# SlidingTackle               1 non-null float64
# GKDiving                    1 non-null float64
# GKHandling                  1 non-null float64
# GKKicking                   1 non-null float64
# GKPositioning               1 non-null float64
# GKReflexes                  1 non-null float64
# dtypes: float64(63), object(14)
# memory usage: 10.5+ MB

# %%
skill_map
# Out:
# {'Player Positions': ['ST'],
#  'Height': "6'2",
#  'Weight': '190lbs',
#  'Position': 'ST',
#  'Jersey Number': '9',
#  'Joined': 'Aug 14, 2019',
#  'Contract Valid Until': '2024',
#  'Preferred Foot': 'Right',
#  'International Reputation': '1',
#  'Weak Foot': '3',
#  'Skill Moves': '3',
#  'Work Rate': 'High/ Medium',
#  'Body Type': 'Normal',
#  'Real Face': 'No',
#  'Release Clause': '€70.7M',
#  'LS': 82,
#  'ST': 82,
#  'RS': 82,
#  'LW': 76,
#  'LF': 80,
#  'CF': 80,
#  'RF': 80,
#  'RW': 76,
#  'LAM': 77,
#  'CAM': 77,
#  'RAM': 77,
#  'LM': 74,
#  'LCM': 72,
#  'CM': 72,
#  'RCM': 72,
#  'RM': 74,
#  'LWB': 55,
#  'LDM': 58,
#  'CDM': 58,
#  'RDM': 58,
#  'RWB': 55,
#  'LB': 52,
#  'LCB': 53,
#  'CB': 53,
#  'RCB': 53,
#  'RB': 52,
#  'Crossing': 50,
#  'Finishing': 86,
#  'HeadingAccuracy': 82,
#  'ShortPassing': 71,
#  'Volleys': 71,
#  'Dribbling': 77,
#  'Curve': 41,
#  'FKAccuracy': 36,
#  'LongPassing': 65,
#  'BallControl': 80,
#  'Acceleration': 65,
#  'SprintSpeed': 69,
#  'Agility': 64,
#  'Reactions': 78,
#  'Balance': 72,
#  'ShotPower': 83,
#  'Jumping': 70,
#  'Stamina': 76,
#  'Strength': 91,
#  'LongShots': 82,
#  'Aggression': 68,
#  'Interceptions': 30,
#  'Positioning': 84,
#  'Vision': 71,
#  'Penalties': 79,
#  'Composure': 82,
#  'DefensiveAwareness': 32,
#  'StandingTackle': 31,
#  'SlidingTackle': 18,
#  'GKDiving': 14,
#  'GKHandling': 12,
#  'GKKicking': 16,
#  'GKPositioning': 13,
#  'GKReflexes': 16}

# %%
skill_map['Player Positions'][0]
# Out:
# 'ST'
